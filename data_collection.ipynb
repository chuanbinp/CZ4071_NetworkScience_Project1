# %% [markdown]
# # CZ4071 Data Collection and Processing
# ##### Author: Phoe Chuan Bin

# %% [markdown]
# ### 0. Import dependencies and set filepaths

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
input_filepath = './Input/DataScientists.xls'
raw_output_filepath = './Input/RawNetworkDataFrame.csv'
processed_output_filepath = './Input/ProcessedNetworkDataFrame.csv'
host_address = 'https://dblp.org/pid/'

# %% [markdown]
# ### 1. Read input file

# %%
input_file = pd.read_excel(input_filepath)
link_addresses = input_file['dblp']

# %% [markdown]
# ### 2. Extract Data
# For each http address in the dblp column:
# 1. Get the PID from the redirected address
# 2. Skip if seen this PID before (prevent duplicates), else update seen list (pid_list) and name mapping (pid_name_mapping)
# 3. Use bs4 to extract xml
# 4. Skip if this PID is non-existent (prevent error if no such records)
# 5. Get all articles and extract ['author_pid','coauthor_pid','year','title']
# 6. Add to dataframe network_df

# %%
pid_list = []
network_df = pd.DataFrame(columns=['author_pid','coauthor_pid','year','title'])
pid_name_mapping = {}

# %%
i = 0
print("Total link addresses:", len(link_addresses))
for link_address in link_addresses:
    r = requests.get(link_address) 
    pid = '/'.join(r.url.split('/')[-2:]).replace('.html','')
    
    # Do not process repeated PID, error checking for duplicate reocrds
    if pid in pid_list:
        print("Skipping repeated PID", pid)
        i+=1
        continue
    pid_list.append(pid)
#     print("pid:", pid)
    
    # Extract data using beautiful soup
    url = host_address + pid + '.xml'
#     print("url:", url)
    xml_data = requests.get(url).content
    soup = BeautifulSoup(xml_data, "xml")
    try:
        # Update pid_name_mapping
        name = soup.find('dblpperson')['name']
        pid_name_mapping[pid] = name
    except:
        print("Skipping invalid PID", pid, ". No such person record.")
        i+=1
        continue
    # Obtain array of articles
    articles = soup.find_all('r')
    
#     print("No. articles:", len(articles))
#     print("Co-authors:")
    # Extract 'year', 'coauthor_pid' and append 'author_pid','coauthor_pid','year' to network_df
    for article in articles:
        article = article.contents[0]
        article_authors = article.find_all('author')
        article_year = article.find('year').string
        article_title = article.find('title').string
        for article_author in article_authors:
            coauthor_pid = article_author['pid']
            if coauthor_pid == pid:
                continue
#             print(coauthor_pid)
            row_data_dict = {'author_pid': pid, 'coauthor_pid': coauthor_pid, 'year': article_year, 'title': article_title}
            network_df = network_df.append(row_data_dict, ignore_index = True)
#         print("Year:", article_year)
#         print()
#     print("-------------------------------------")
    i+=1
    print("Processed link address", i)
# Out:
# Total link addresses: 1220
# Processed link address 1
# Processed link address 2
# Processed link address 3
# Processed link address 4
# Processed link address 5
# Processed link address 6
# Processed link address 7
# Processed link address 8
# Skipping repeated PID 04/7892
# Processed link address 10
# Processed link address 11
# Processed link address 12
# Processed link address 13
# Processed link address 14
# Processed link address 15
# Processed link address 16
# Skipping repeated PID k/AlfonsKemper
# Processed link address 18
# Processed link address 19
# Processed link address 20
# Processed link address 21
# Processed link address 22
# Processed link address 23
# Processed link address 24
# Processed link address 25
# Skipping repeated PID h/AlonYHalevy
# Processed link address 27
# Processed link address 28
# Processed link address 29
# Processed link address 30
# Processed link address 31
# Skipping repeated PID 136/7882
# Processed link address 33
# Processed link address 34
# Processed link address 35
# Processed link address 36
# Processed link address 37
# Processed link address 38
# Processed link address 39
# Processed link address 40
# Processed link address 41
# Processed link address 42
# Processed link address 43
# Processed link address 44
# Processed link address 45
# Processed link address 46
# Processed link address 47
# Processed link address 48
# Processed link address 49
# Processed link address 50
# Processed link address 51
# Processed link address 52
# Processed link address 53
# Processed link address 54
# Processed link address 55
# Processed link address 56
# Processed link address 57
# Skipping repeated PID 54/385-1
# Processed link address 59
# Skipping repeated PID 81/10578
# Processed link address 61
# Skipping repeated PID 29/11192
# Processed link address 63
# Processed link address 64
# Processed link address 65
# Processed link address 66
# Processed link address 67
# Skipping repeated PID t/AnthonyKHTung
# Skipping repeated PID t/AnthonyKHTung
# Processed link address 70
# Skipping repeated PID 96/11411
# Processed link address 72
# Skipping repeated PID d/ADeligiannakis
# Skipping repeated PID d/ADeligiannakis
# Processed link address 75
# Processed link address 76
# Processed link address 77
# Processed link address 78
# Processed link address 79
# Processed link address 80
# Skipping repeated PID t/ArashTermehchy
# Processed link address 82
# Processed link address 83
# Processed link address 84
# Processed link address 85
# Processed link address 86
# Processed link address 87
# Processed link address 88
# Processed link address 89
# Processed link address 90
# Processed link address 91
# Processed link address 92
# Processed link address 93
# Processed link address 94
# Processed link address 95
# Processed link address 96
# Processed link address 97
# Processed link address 98
# Processed link address 99
# Processed link address 100
# Processed link address 101
# Processed link address 102
# Processed link address 103
# Processed link address 104
# Processed link address 105
# Processed link address 106
# Processed link address 107
# Skipping repeated PID h/BingshengHe
# Processed link address 109
# Processed link address 110
# Processed link address 111
# Processed link address 112
# Processed link address 113
# Processed link address 114
# Skipping repeated PID 46/3522
# Processed link address 116
# Processed link address 117
# Processed link address 118
# Processed link address 119
# Processed link address 120
# Skipping repeated PID 180/5761
# Processed link address 122
# Processed link address 123
# Skipping repeated PID 07/1560
# Processed link address 125
# Processed link address 126
# Processed link address 127
# Processed link address 128
# Skipping repeated PID 74/20
# Processed link address 130
# Processed link address 131
# Processed link address 132
# Skipping repeated PID c/CarloCurino
# Processed link address 134
# Processed link address 135
# Processed link address 136
# Processed link address 137
# Processed link address 138
# Processed link address 139
# Processed link address 140
# Processed link address 141
# Processed link address 142
# Processed link address 143
# Processed link address 144
# Processed link address 145
# Processed link address 146
# Processed link address 147
# Processed link address 148
# Skipping invalid PID 148/7268 . No such person record.
# Processed link address 150
# Processed link address 151
# Processed link address 152
# Processed link address 153
# Processed link address 154
# Processed link address 155
# Processed link address 156
# Skipping repeated PID 14/3692
# Skipping repeated PID 14/3692
# Processed link address 159
# Processed link address 160
# Processed link address 161
# Processed link address 162
# Processed link address 163
# Processed link address 164
# Processed link address 165
# Processed link address 166
# Processed link address 167
# Processed link address 168
# Processed link address 169
# Processed link address 170
# Processed link address 171
# Processed link address 172
# Skipping repeated PID 87/10957
# Processed link address 174
# Processed link address 175
# Processed link address 176
# Processed link address 177
# Processed link address 178
# Processed link address 179
# Processed link address 180
# Processed link address 181
# Processed link address 182
# Processed link address 183
# Processed link address 184
# Processed link address 185
# Processed link address 186
# Skipping repeated PID 27/2143
# Processed link address 188
# Processed link address 189
# Processed link address 190
# Processed link address 191
# Processed link address 192
# Processed link address 193
# Processed link address 194
# Skipping repeated PID a/DJAbadi
# Processed link address 196
# Skipping repeated PID 98/6876
# Processed link address 198
# Processed link address 199
# Processed link address 200
# Processed link address 201
# Processed link address 202
# Processed link address 203
# Skipping repeated PID 54/1720
# Processed link address 205
# Processed link address 206
# Processed link address 207
# Processed link address 208
# Processed link address 209
# Processed link address 210
# Processed link address 211
# Processed link address 212
# Processed link address 213
# Processed link address 214
# Processed link address 215
# Processed link address 216
# Processed link address 217
# Processed link address 218
# Processed link address 219
# Processed link address 220
# Processed link address 221
# Processed link address 222
# Processed link address 223
# Processed link address 224
# Processed link address 225
# Processed link address 226
# Processed link address 227
# Processed link address 228
# Processed link address 229
# Processed link address 230
# Processed link address 231
# Processed link address 232
# Skipping repeated PID 71/8700-1
# Processed link address 234
# Processed link address 235
# Processed link address 236
# Processed link address 237
# Processed link address 238
# Processed link address 239
# Processed link address 240
# Processed link address 241
# Processed link address 242
# Processed link address 243
# Processed link address 244
# Processed link address 245
# Processed link address 246
# Processed link address 247
# Processed link address 248
# Processed link address 249
# Processed link address 250
# Processed link address 251
# Processed link address 252
# Processed link address 253
# Processed link address 254
# Skipping repeated PID 55/6899
# Processed link address 256
# Skipping repeated PID 31/9364
# Processed link address 258
# Processed link address 259
# Processed link address 260
# Processed link address 261
# Processed link address 262
# Processed link address 263
# Skipping repeated PID m/EssamMansour
# Processed link address 265
# Processed link address 266
# Skipping repeated PID 41/3679
# Processed link address 268
# Processed link address 269
# Processed link address 270
# Processed link address 271
# Processed link address 272
# Processed link address 273
# Processed link address 274
# Skipping repeated PID o/FatmaOzcan
# Processed link address 276
# Processed link address 277
# Processed link address 278
# Processed link address 279
# Skipping repeated PID 77/1985
# Processed link address 281
# Processed link address 282
# Processed link address 283
# Processed link address 284
# Processed link address 285
# Processed link address 286
# Processed link address 287
# Processed link address 288
# Processed link address 289
# Processed link address 290
# Processed link address 291
# Processed link address 292
# Processed link address 293
# Processed link address 294
# Processed link address 295
# Skipping repeated PID b/FBonchi
# Processed link address 297
# Processed link address 298
# Processed link address 299
# Processed link address 300
# Processed link address 301
# Processed link address 302
# Processed link address 303
# Processed link address 304
# Processed link address 305
# Processed link address 306
# Processed link address 307
# Processed link address 308
# Processed link address 309
# Processed link address 310
# Processed link address 311
# Processed link address 312
# Processed link address 313
# Skipping repeated PID f/GeorgeHLFletcher
# Processed link address 315
# Processed link address 316
# Skipping repeated PID 32/1624
# Processed link address 318
# Processed link address 319
# Skipping repeated PID k/GeorgiaKoutrika
# Skipping repeated PID k/GeorgiaKoutrika
# Processed link address 322
# Processed link address 323
# Processed link address 324
# Processed link address 325
# Processed link address 326
# Processed link address 327
# Processed link address 328
# Skipping repeated PID 151/8293
# Processed link address 330
# Processed link address 331
# Processed link address 332
# Processed link address 333
# Processed link address 334
# Processed link address 335
# Processed link address 336
# Processed link address 337
# Processed link address 338
# Processed link address 339
# Processed link address 340
# Processed link address 341
# Processed link address 342
# Processed link address 343
# Processed link address 344
# Processed link address 345
# Processed link address 346
# Processed link address 347
# Processed link address 348
# Processed link address 349
# Processed link address 350
# Skipping repeated PID f/HFerhatosmanoglu
# Processed link address 352
# Processed link address 353
# Processed link address 354
# Processed link address 355
# Processed link address 356
# Processed link address 357
# Processed link address 358
# Processed link address 359
# Processed link address 360
# Processed link address 361
# Skipping repeated PID m/HeikoMuller
# Processed link address 363
# Processed link address 364
# Processed link address 365
# Processed link address 366
# Skipping invalid PID 98/5721 . No such person record.
# Processed link address 368
# Processed link address 369
# Processed link address 370
# Processed link address 371
# Processed link address 372
# Skipping repeated PID 08/3969
# Skipping repeated PID 08/3969
# Processed link address 375
# Processed link address 376
# Processed link address 377
# Processed link address 378
# Processed link address 379
# Processed link address 380
# Skipping repeated PID l/HuaLu
# Processed link address 382
# Processed link address 383
# Skipping repeated PID 13/8730
# Processed link address 385
# Skipping repeated PID l/HuiLi5
# Processed link address 387
# Processed link address 388
# Processed link address 389
# Processed link address 390
# Processed link address 391
# Processed link address 392
# Processed link address 393
# Processed link address 394
# Processed link address 395
# Processed link address 396
# Skipping repeated PID p/IliaPetrov
# Processed link address 398
# Skipping repeated PID 85/9079
# Processed link address 400
# Processed link address 401
# Processed link address 402
# Processed link address 403
# Processed link address 404
# Processed link address 405
# Processed link address 406
# Skipping repeated PID s/IonStoica
# Processed link address 408
# Skipping repeated PID p/IppokratisPandis
# Processed link address 410
# Processed link address 411
# Processed link address 412
# Processed link address 413
# Processed link address 414
# Processed link address 415
# Processed link address 416
# Processed link address 417
# Processed link address 418
# Processed link address 419
# Processed link address 420
# Processed link address 421
# Processed link address 422
# Processed link address 423
# Processed link address 424
# Processed link address 425
# Processed link address 426
# Processed link address 427
# Processed link address 428
# Processed link address 429
# Processed link address 430
# Skipping repeated PID 129/8181
# Processed link address 432
# Processed link address 433
# Processed link address 434
# Processed link address 435
# Processed link address 436
# Processed link address 437
# Processed link address 438
# Processed link address 439
# Skipping repeated PID d/JensPeterDittrich
# Processed link address 441
# Processed link address 442
# Processed link address 443
# Processed link address 444
# Processed link address 445
# Processed link address 446
# Processed link address 447
# Skipping repeated PID p/JianPei
# Processed link address 449
# Processed link address 450
# Processed link address 451
# Processed link address 452
# Processed link address 453
# Processed link address 454
# Processed link address 455
# Processed link address 456
# Processed link address 457
# Processed link address 458
# Processed link address 459
# Processed link address 460
# Processed link address 461
# Skipping repeated PID 89/9935
# Processed link address 463
# Processed link address 464
# Processed link address 465
# Processed link address 466
# Processed link address 467
# Skipping repeated PID 14/10827
# Processed link address 469
# Processed link address 470
# Processed link address 471
# Processed link address 472
# Processed link address 473
# Processed link address 474
# Processed link address 475
# Skipping repeated PID 59/6952
# Processed link address 477
# Processed link address 478
# Processed link address 479
# Processed link address 480
# Processed link address 481
# Processed link address 482
# Processed link address 483
# Processed link address 484
# Processed link address 485
# Processed link address 486
# Processed link address 487
# Processed link address 488
# Processed link address 489
# Processed link address 490
# Processed link address 491
# Processed link address 492
# Processed link address 493
# Skipping repeated PID 127/3025
# Processed link address 495
# Processed link address 496
# Skipping repeated PID s/JuliaStoyanovich
# Processed link address 498
# Processed link address 499
# Processed link address 500
# Processed link address 501
# Processed link address 502
# Processed link address 503
# Processed link address 504
# Processed link address 505
# Processed link address 506
# Processed link address 507
# Skipping repeated PID 02/3658
# Processed link address 509
# Processed link address 510
# Processed link address 511
# Processed link address 512
# Processed link address 513
# Processed link address 514
# Processed link address 515
# Processed link address 516
# Processed link address 517
# Processed link address 518
# Processed link address 519
# Processed link address 520
# Processed link address 521
# Processed link address 522
# Processed link address 523
# Skipping repeated PID 230/0570
# Processed link address 525
# Processed link address 526
# Processed link address 527
# Processed link address 528
# Skipping repeated PID 51/792-2
# Processed link address 530
# Processed link address 531
# Processed link address 532
# Processed link address 533
# Processed link address 534
# Processed link address 535
# Processed link address 536
# Processed link address 537
# Processed link address 538
# Processed link address 539
# Processed link address 540
# Processed link address 541
# Processed link address 542
# Processed link address 543
# Processed link address 544
# Processed link address 545
# Processed link address 546
# Processed link address 547
# Processed link address 548
# Skipping repeated PID 59/7992
# Processed link address 550
# Processed link address 551
# Processed link address 552
# Processed link address 553
# Processed link address 554
# Processed link address 555
# Processed link address 556
# Processed link address 557
# Processed link address 558
# Processed link address 559
# Processed link address 560
# Processed link address 561
# Processed link address 562
# Processed link address 563
# Processed link address 564
# Processed link address 565
# Processed link address 566
# Processed link address 567
# Processed link address 568
# Processed link address 569
# Processed link address 570
# Processed link address 571
# Processed link address 572
# Skipping repeated PID 69/157-1
# Processed link address 574
# Processed link address 575
# Processed link address 576
# Processed link address 577
# Processed link address 578
# Processed link address 579
# Processed link address 580
# Processed link address 581
# Processed link address 582
# Processed link address 583
# Processed link address 584
# Skipping repeated PID 81/10470
# Processed link address 586
# Processed link address 587
# Skipping repeated PID 200/8759
# Processed link address 589
# Processed link address 590
# Processed link address 591
# Processed link address 592
# Processed link address 593
# Processed link address 594
# Processed link address 595
# Processed link address 596
# Processed link address 597
# Processed link address 598
# Processed link address 599
# Processed link address 600
# Processed link address 601
# Processed link address 602
# Processed link address 603
# Processed link address 604
# Processed link address 605
# Processed link address 606
# Processed link address 607
# Processed link address 608
# Processed link address 609
# Processed link address 610
# Processed link address 611
# Processed link address 612
# Processed link address 613
# Skipping repeated PID t/MartinTheobald
# Processed link address 615
# Processed link address 616
# Processed link address 617
# Processed link address 618
# Processed link address 619
# Processed link address 620
# Skipping repeated PID 49/10034
# Processed link address 622
# Processed link address 623
# Processed link address 624
# Processed link address 625
# Skipping repeated PID 75/887
# Skipping repeated PID 75/887
# Processed link address 628
# Processed link address 629
# Skipping repeated PID r/MatthiasRenz
# Processed link address 631
# Processed link address 632
# Processed link address 633
# Processed link address 634
# Processed link address 635
# Processed link address 636
# Processed link address 637
# Processed link address 638
# Skipping repeated PID 181/5823
# Processed link address 640
# Processed link address 641
# Skipping repeated PID 96/4770
# Processed link address 643
# Skipping repeated PID 186/1469
# Processed link address 645
# Processed link address 646
# Processed link address 647
# Processed link address 648
# Processed link address 649
# Processed link address 650
# Processed link address 651
# Processed link address 652
# Processed link address 653
# Processed link address 654
# Processed link address 655
# Skipping repeated PID 82/231
# Processed link address 657
# Processed link address 658
# Processed link address 659
# Processed link address 660
# Skipping repeated PID 10/5842
# Processed link address 662
# Processed link address 663
# Skipping repeated PID 20/9709
# Processed link address 665
# Processed link address 666
# Processed link address 667
# Processed link address 668
# Processed link address 669
# Processed link address 670
# Processed link address 671
# Processed link address 672
# Processed link address 673
# Processed link address 674
# Processed link address 675
# Processed link address 676
# Processed link address 677
# Skipping repeated PID 94/5893
# Processed link address 679
# Processed link address 680
# Processed link address 681
# Skipping repeated PID s/MohamedASharaf
# Processed link address 683
# Processed link address 684
# Processed link address 685
# Processed link address 686
# Skipping repeated PID 56/7016
# Skipping repeated PID 56/7016
# Processed link address 689
# Processed link address 690
# Processed link address 691
# Processed link address 692
# Processed link address 693
# Processed link address 694
# Processed link address 695
# Processed link address 696
# Processed link address 697
# Processed link address 698
# Processed link address 699
# Processed link address 700
# Processed link address 701
# Processed link address 702
# Processed link address 703
# Skipping repeated PID p/NeoklisPolyzotis
# Processed link address 705
# Processed link address 706
# Processed link address 707
# Processed link address 708
# Processed link address 709
# Processed link address 710
# Processed link address 711
# Skipping repeated PID 13/8165
# Processed link address 713
# Processed link address 714
# Processed link address 715
# Processed link address 716
# Processed link address 717
# Processed link address 718
# Processed link address 719
# Processed link address 720
# Skipping repeated PID 34/6253
# Processed link address 722
# Processed link address 723
# Processed link address 724
# Processed link address 725
# Processed link address 726
# Skipping repeated PID l/NinghuiLi
# Processed link address 728
# Processed link address 729
# Processed link address 730
# Processed link address 731
# Processed link address 732
# Processed link address 733
# Processed link address 734
# Processed link address 735
# Processed link address 736
# Processed link address 737
# Processed link address 738
# Skipping repeated PID p/OdysseasPapapetrou
# Processed link address 740
# Processed link address 741
# Processed link address 742
# Skipping repeated PID 71/7422
# Processed link address 744
# Processed link address 745
# Processed link address 746
# Processed link address 747
# Processed link address 748
# Processed link address 749
# Processed link address 750
# Skipping repeated PID 08/5342
# Processed link address 752
# Processed link address 753
# Processed link address 754
# Processed link address 755
# Processed link address 756
# Processed link address 757
# Processed link address 758
# Processed link address 759
# Skipping repeated PID m/PaoloMerialdo
# Processed link address 761
# Skipping repeated PID 28/1062
# Processed link address 763
# Processed link address 764
# Processed link address 765
# Skipping repeated PID 49/8316
# Processed link address 767
# Processed link address 768
# Processed link address 769
# Processed link address 770
# Processed link address 771
# Skipping repeated PID 18/4350
# Processed link address 773
# Processed link address 774
# Processed link address 775
# Processed link address 776
# Processed link address 777
# Processed link address 778
# Processed link address 779
# Processed link address 780
# Processed link address 781
# Skipping repeated PID 45/4887
# Processed link address 783
# Processed link address 784
# Processed link address 785
# Processed link address 786
# Processed link address 787
# Processed link address 788
# Processed link address 789
# Processed link address 790
# Processed link address 791
# Processed link address 792
# Processed link address 793
# Processed link address 794
# Processed link address 795
# Processed link address 796
# Skipping repeated PID 198/5418
# Processed link address 798
# Processed link address 799
# Processed link address 800
# Processed link address 801
# Processed link address 802
# Processed link address 803
# Processed link address 804
# Processed link address 805
# Processed link address 806
# Processed link address 807
# Processed link address 808
# Processed link address 809
# Processed link address 810
# Processed link address 811
# Processed link address 812
# Processed link address 813
# Skipping repeated PID 79/3108
# Processed link address 815
# Processed link address 816
# Processed link address 817
# Processed link address 818
# Processed link address 819
# Processed link address 820
# Processed link address 821
# Processed link address 822
# Processed link address 823
# Processed link address 824
# Processed link address 825
# Processed link address 826
# Processed link address 827
# Processed link address 828
# Processed link address 829
# Processed link address 830
# Processed link address 831
# Processed link address 832
# Processed link address 833
# Processed link address 834
# Skipping repeated PID 56/3378
# Processed link address 836
# Processed link address 837
# Processed link address 838
# Processed link address 839
# Processed link address 840
# Processed link address 841
# Skipping repeated PID w/RaymondChiWingWong
# Processed link address 843
# Processed link address 844
# Skipping repeated PID 147/1198
# Processed link address 846
# Processed link address 847
# Processed link address 848
# Skipping repeated PID m/ReneMuller
# Processed link address 850
# Skipping repeated PID m/RJMiller
# Skipping repeated PID m/RJMiller
# Processed link address 853
# Processed link address 854
# Processed link address 855
# Processed link address 856
# Processed link address 857
# Processed link address 858
# Processed link address 859
# Processed link address 860
# Processed link address 861
# Processed link address 862
# Processed link address 863
# Processed link address 864
# Processed link address 865
# Processed link address 866
# Processed link address 867
# Processed link address 868
# Skipping repeated PID 37/548
# Processed link address 870
# Processed link address 871
# Processed link address 872
# Processed link address 873
# Processed link address 874
# Skipping repeated PID 03/505
# Skipping repeated PID 03/505
# Processed link address 877
# Processed link address 878
# Processed link address 879
# Processed link address 880
# Skipping repeated PID 98/3414-1
# Processed link address 882
# Processed link address 883
# Processed link address 884
# Processed link address 885
# Processed link address 886
# Processed link address 887
# Processed link address 888
# Processed link address 889
# Processed link address 890
# Processed link address 891
# Processed link address 892
# Processed link address 893
# Processed link address 894
# Processed link address 895
# Processed link address 896
# Processed link address 897
# Processed link address 898
# Processed link address 899
# Skipping repeated PID 11/7555
# Processed link address 901
# Processed link address 902
# Processed link address 903
# Processed link address 904
# Processed link address 905
# Processed link address 906
# Processed link address 907
# Processed link address 908
# Processed link address 909
# Skipping repeated PID 57/10514
# Processed link address 911
# Processed link address 912
# Processed link address 913
# Processed link address 914
# Processed link address 915
# Processed link address 916
# Processed link address 917
# Processed link address 918
# Processed link address 919
# Processed link address 920
# Processed link address 921
# Processed link address 922
# Skipping repeated PID 83/2389-1
# Processed link address 924
# Processed link address 925
# Processed link address 926
# Processed link address 927
# Processed link address 928
# Processed link address 929
# Processed link address 930
# Processed link address 931
# Processed link address 932
# Processed link address 933
# Processed link address 934
# Processed link address 935
# Processed link address 936
# Processed link address 937
# Processed link address 938
# Processed link address 939
# Processed link address 940
# Processed link address 941
# Processed link address 942
# Processed link address 943
# Skipping repeated PID 35/6569
# Processed link address 945
# Processed link address 946
# Processed link address 947
# Processed link address 948
# Processed link address 949
# Processed link address 950
# Processed link address 951
# Processed link address 952
# Processed link address 953
# Processed link address 954
# Processed link address 955
# Processed link address 956
# Skipping repeated PID w/StevenEuijongWhang
# Processed link address 958
# Skipping repeated PID 28/3797
# Processed link address 960
# Processed link address 961
# Skipping repeated PID 139/7927
# Processed link address 963
# Processed link address 964
# Processed link address 965
# Processed link address 966
# Processed link address 967
# Processed link address 968
# Skipping repeated PID 44/4775-2
# Processed link address 970
# Skipping repeated PID 71/5974
# Processed link address 972
# Processed link address 973
# Processed link address 974
# Processed link address 975
# Processed link address 976
# Processed link address 977
# Processed link address 978
# Processed link address 979
# Processed link address 980
# Processed link address 981
# Processed link address 982
# Processed link address 983
# Processed link address 984
# Processed link address 985
# Processed link address 986
# Processed link address 987
# Processed link address 988
# Skipping repeated PID 11/7631
# Processed link address 990
# Processed link address 991
# Processed link address 992
# Processed link address 993
# Processed link address 994
# Processed link address 995
# Processed link address 996
# Skipping repeated PID s/TimosKSellis
# Processed link address 998
# Processed link address 999
# Processed link address 1000
# Skipping repeated PID y/TingYu
# Processed link address 1002
# Skipping repeated PID 25/2228
# Processed link address 1004
# Processed link address 1005
# Processed link address 1006
# Processed link address 1007
# Processed link address 1008
# Processed link address 1009
# Processed link address 1010
# Processed link address 1011
# Processed link address 1012
# Processed link address 1013
# Processed link address 1014
# Processed link address 1015
# Processed link address 1016
# Processed link address 1017
# Processed link address 1018
# Processed link address 1019
# Processed link address 1020
# Processed link address 1021
# Processed link address 1022
# Processed link address 1023
# Processed link address 1024
# Processed link address 1025
# Processed link address 1026
# Processed link address 1027
# Processed link address 1028
# Processed link address 1029
# Processed link address 1030
# Processed link address 1031
# Processed link address 1032
# Processed link address 1033
# Processed link address 1034
# Skipping repeated PID c/VassilisChristophides
# Processed link address 1036
# Processed link address 1037
# Processed link address 1038
# Processed link address 1039
# Skipping repeated PID k/VerenaKantere
# Skipping repeated PID k/VerenaKantere
# Processed link address 1042
# Processed link address 1043
# Processed link address 1044
# Processed link address 1045
# Skipping repeated PID 06/8397
# Processed link address 1047
# Processed link address 1048
# Processed link address 1049
# Processed link address 1050
# Processed link address 1051
# Skipping repeated PID 10/11150
# Skipping repeated PID 10/11150
# Processed link address 1054
# Processed link address 1055
# Processed link address 1056
# Processed link address 1057
# Processed link address 1058
# Processed link address 1059
# Processed link address 1060
# Processed link address 1061
# Processed link address 1062
# Processed link address 1063
# Processed link address 1064
# Processed link address 1065
# Processed link address 1066
# Processed link address 1067
# Skipping repeated PID a/WGAref
# Processed link address 1069
# Processed link address 1070
# Processed link address 1071
# Processed link address 1072
# Processed link address 1073
# Processed link address 1074
# Skipping repeated PID c/WeiChen1
# Processed link address 1076
# Processed link address 1077
# Skipping repeated PID 98/6613-15
# Processed link address 1079
# Processed link address 1080
# Processed link address 1081
# Processed link address 1082
# Skipping repeated PID 35/7092-59
# Processed link address 1084
# Skipping repeated PID w/WeiWang11
# Processed link address 1086
# Processed link address 1087
# Processed link address 1088
# Processed link address 1089
# Skipping repeated PID 21/1694
# Processed link address 1091
# Processed link address 1092
# Processed link address 1093
# Processed link address 1094
# Processed link address 1095
# Processed link address 1096
# Processed link address 1097
# Skipping repeated PID 62/2450
# Processed link address 1099
# Processed link address 1100
# Skipping repeated PID 28/949-1
# Skipping repeated PID 28/949-1
# Processed link address 1103
# Processed link address 1104
# Processed link address 1105
# Processed link address 1106
# Processed link address 1107
# Skipping repeated PID 126/6015
# Processed link address 1109
# Processed link address 1110
# Processed link address 1111
# Processed link address 1112
# Processed link address 1113
# Processed link address 1114
# Processed link address 1115
# Processed link address 1116
# Processed link address 1117
# Processed link address 1118
# Skipping repeated PID d/XinLunaDong
# Processed link address 1120
# Skipping repeated PID 98/5766-1
# Processed link address 1122
# Processed link address 1123
# Processed link address 1124
# Processed link address 1125
# Processed link address 1126
# Processed link address 1127
# Processed link address 1128
# Processed link address 1129
# Processed link address 1130
# Processed link address 1131
# Processed link address 1132
# Processed link address 1133
# Processed link address 1134
# Processed link address 1135
# Skipping repeated PID 88/9060
# Processed link address 1137
# Processed link address 1138
# Processed link address 1139
# Processed link address 1140
# Processed link address 1141
# Processed link address 1142
# Processed link address 1143
# Processed link address 1144
# Processed link address 1145
# Skipping repeated PID 74/2905
# Processed link address 1147
# Processed link address 1148
# Processed link address 1149
# Processed link address 1150
# Skipping repeated PID 33/6315-1
# Skipping repeated PID 33/6315-1
# Processed link address 1153
# Processed link address 1154
# Processed link address 1155
# Processed link address 1156
# Processed link address 1157
# Skipping repeated PID 43/1219-1
# Processed link address 1159
# Processed link address 1160
# Skipping repeated PID 171/4868
# Processed link address 1162
# Processed link address 1163
# Processed link address 1164
# Processed link address 1165
# Processed link address 1166
# Processed link address 1167
# Skipping repeated PID 32/6122
# Processed link address 1169
# Processed link address 1170
# Processed link address 1171
# Processed link address 1172
# Processed link address 1173
# Skipping repeated PID 76/1735
# Processed link address 1175
# Processed link address 1176
# Processed link address 1177
# Processed link address 1178
# Processed link address 1179
# Processed link address 1180
# Processed link address 1181
# Processed link address 1182
# Processed link address 1183
# Processed link address 1184
# Skipping repeated PID 160/1053
# Skipping repeated PID 160/1053
# Processed link address 1187
# Processed link address 1188
# Skipping repeated PID t/YufeiTao
# Processed link address 1190
# Processed link address 1191
# Skipping repeated PID 172/5536
# Processed link address 1193
# Processed link address 1194
# Processed link address 1195
# Processed link address 1196
# Processed link address 1197
# Processed link address 1198
# Processed link address 1199
# Processed link address 1200
# Skipping repeated PID 117/3757
# Processed link address 1202
# Processed link address 1203
# Processed link address 1204
# Processed link address 1205
# Processed link address 1206
# Processed link address 1207
# Processed link address 1208
# Processed link address 1209
# Processed link address 1210
# Skipping repeated PID 169/3419
# Processed link address 1212
# Processed link address 1213
# Processed link address 1214
# Processed link address 1215
# Processed link address 1216
# Processed link address 1217
# Skipping repeated PID 65/1457
# Processed link address 1219
# Processed link address 1220

# %% [markdown]
# ### 3. Save extracted raw data

# %%
network_df
# Out:
#        author_pid coauthor_pid  year  \
# 0         75/9436     147/1343  2021
# 1         75/9436      38/6049  2021
# 2         75/9436     163/0545  2021
# 3         75/9436      05/7063  2021
# 4         75/9436     131/4166  2021
# ...           ...          ...   ...
# 362947   146/6971     188/6434  2016
# 362948   146/6971     48/450-7  2013
# 362949   146/6971      85/5485  2013
# 362950   146/6971    89/6609-1  2013
# 362951   146/6971      28/4847  2013
#
#                                                     title
# 0       Decomposed Bounded Floats for Fast Compression...
# 1       Decomposed Bounded Floats for Fast Compression...
# 2       Decomposed Bounded Floats for Fast Compression...
# 3       A Demonstration of Relic: A System for REtrosp...
# 4       A Demonstration of Relic: A System for REtrosp...
# ...                                                   ...
# 362947  RadioHound: A Pervasive Sensing Network for Su...
# 362948  Transmission capacity of device-to-device comm...
# 362949  Transmission capacity of device-to-device comm...
# 362950  Transmission capacity of device-to-device comm...
# 362951  Transmission capacity of device-to-device comm...
#
# [362952 rows x 4 columns]

# %%
# Save raw
network_df.to_csv(raw_output_filepath, index=False)

# %% [markdown]
# ### 4. Process raw data
# - Remove individuals not in the network using seen list (pid_list)
# - Add author_name and coauthor_name columns using name mapping (pid_name_mapping)
# - Remove duplicates since edges are bidirectional, remove if row data is same when author and coauthor is swapped

# %%
pid_list
# Out:
# ['75/9436',
#  '162/9092',
#  '127/6195',
#  '121/4198',
#  '116/1678',
#  '39/1380',
#  '139/0855',
#  '04/7892',
#  'j/AdamJatowt',
#  '62/1373',
#  '21/8510',
#  '04/1835',
#  'l/ALabrinidis',
#  '92/2820',
#  'k/AlfonsKemper',
#  '159/6520',
#  'd/AlinDeutsch',
#  '134/9031',
#  '164/1401',
#  'p/NeoklisPolyzotis',
#  's/ASimitsis',
#  '163/3911',
#  'h/AlonYHalevy',
#  's/ASdaSilva',
#  '16/4915',
#  's/AmbujKSingh',
#  '131/6619',
#  '136/7882',
#  '67/2583',
#  '77/5034',
#  '75/5002',
#  'd/AmolDeshpande',
#  'a/AmrElAbbadi',
#  '05/8073-1',
#  '160/4306',
#  '127/1469',
#  '37/10133-3',
#  '26/2579',
#  'a/AnastassiaAilamaki',
#  'c/AndreaCali',
#  'h/AndreasHotho',
#  '167/6469',
#  '38/2946',
#  '18/2478',
#  '222/3221',
#  '147/4971',
#  '58/4127',
#  '218/6513',
#  'b/ABonifati',
#  'd/AnHaiDoan',
#  'm/AnimeshMukherjee',
#  '73/2286',
#  '54/385-1',
#  '81/10578',
#  '29/11192',
#  's/AnnaCinziaSquicciarini',
#  '63/5512',
#  '63/9828',
#  '147/1241',
#  't/AnthonyKHTung',
#  '96/11411',
#  'd/ADeligiannakis',
#  '163/0449',
#  'z/AoyingZhou',
#  '183/5034',
#  '20/3559',
#  'p/ANPapadopoulos',
#  't/ArashTermehchy',
#  'c/ALPChen',
#  '16/5085',
#  '67/2933',
#  '34/5594',
#  'g/AristidesGionis',
#  '19/2546',
#  '48/2626-1',
#  '66/3027',
#  '45/2495',
#  '83/11148',
#  '200/8321',
#  '61/5238',
#  'k/BenKao',
#  'o/BengChinOoi',
#  '218/5225',
#  '74/3195',
#  '51/6689',
#  'a/BAmann',
#  'l/BertramLudascher',
#  'k/BettinaKemme',
#  '131/6284',
#  'h/BillHowe',
#  '55/5031',
#  '98/4432-3',
#  '77/377-2',
#  'h/BingshengHe',
#  '33/4411',
#  'k/BKonigRies',
#  'j/BjornTorJonsson1',
#  '50/3402-1',
#  '26/1194-23',
#  '46/3522',
#  '152/4895',
#  '20/6358',
#  '75/3108',
#  '09/3012',
#  '180/5761',
#  '185/4349',
#  '07/1560',
#  'm/CMohan',
#  'j/CVJawahar',
#  't/CaetanoTrainaJr',
#  '74/20',
#  '193/1652',
#  '149/1789',
#  'c/CarloCurino',
#  '17/5910',
#  '26/3914',
#  'r/CarolinaRuiz',
#  '45/1559',
#  '28/10108',
#  '97/919-1',
#  '122/5424-2',
#  '08/4367',
#  '170/5430',
#  '18/4087-1',
#  '94/3019-45',
#  '13/1672',
#  'c/CheeYongChan',
#  'l/ChenLi1',
#  '92/2769',
#  '148/7268',
#  '82/4206-11',
#  '33/11343',
#  '58/10813',
#  '49/1457-2',
#  'l/ChengfeiLiu',
#  '51/3529-1',
#  '14/3692',
#  '52/9457',
#  '18/10886',
#  '09/404-1',
#  '38/8845',
#  'r/ChinyaVRavishankar',
#  'b/CBhattacharyya',
#  '198/4308',
#  'j/ChrisJermaine',
#  'b/ChristianBizer',
#  'j/ChristianSJensen',
#  'k/ChristophKoch',
#  '154/6336',
#  'r/ChristopherRe',
#  '87/10957',
#  '64/3041',
#  '57/4384-1',
#  '20/1969-1',
#  '82/11411',
#  '65/3446',
#  '58/3771',
#  '116/0694',
#  '69/6680',
#  'd/CEDyreson',
#  's/CyrusShahabi',
#  '81/9436-1',
#  '223/3148',
#  '27/2143',
#  '84/114',
#  '03/6105',
#  's/DanSuciu',
#  '154/0932',
#  'y/DanfengYao',
#  '69/9726',
#  'a/DJAbadi',
#  '98/6876',
#  '40/6300',
#  '68/7553-1',
#  '93/9012',
#  '133/1954',
#  'c/DarioColazzo',
#  '54/1720',
#  '14/6896',
#  '135/7623',
#  'r/DRafiei',
#  'm/DebapriyoMajumdar',
#  '41/7272',
#  '65/6758',
#  '33/1882',
#  'z/DemetriosZeinalipourYazti',
#  '85/318',
#  'b/DBarbosa',
#  '83/8652',
#  '82/2760',
#  'g/DimitriosGunopulos',
#  'p/DimitrisPapadias',
#  '19/4428',
#  '94/4438',
#  '81/6181',
#  '43/6688',
#  's/DiveshSrivastava',
#  'a/DivyakantAgrawal',
#  '161/0102',
#  '155/5478',
#  '70/11145',
#  '09/10814',
#  '147/1186',
#  'k/DonaldKossmann',
#  '05/10127',
#  '71/8700-1',
#  '20/6977-1',
#  '33/6749',
#  '89/6013',
#  '03/10118',
#  '37/640',
#  '151/2098',
#  '78/5231',
#  '66/6919',
#  '24/788',
#  'f/EdwardAFox',
#  '04/1538',
#  '68/3366',
#  '77/5283',
#  '84/2154',
#  'f/ElenaFerrari',
#  '164/7451',
#  '225/2019',
#  'b/ElisaBertino',
#  'r/EARundensteiner',
#  '96/8919',
#  '55/6899',
#  '31/9364',
#  'r/ERahm',
#  '80/2320',
#  '88/6520',
#  '116/5135',
#  '54/6752',
#  'm/EssamMansour',
#  '177/8852',
#  '41/3679',
#  '81/4388',
#  'p/EPitoura',
#  '21/3626-36',
#  '34/508',
#  't/FaroukToumani',
#  '23/7274',
#  'o/FatmaOzcan',
#  '66/2556',
#  '51/394-1',
#  '84/3254-5',
#  '77/1985',
#  'l/FeifeiLi',
#  'n/FelixNaumann',
#  '129/6818',
#  '48/1294-7',
#  '04/5404',
#  '167/4770',
#  '14/4251',
#  'k/FlipKorn',
#  '284/0968',
#  '26/5304',
#  '73/343',
#  'g/FlorisGeerts',
#  '135/5141',
#  'a/FotoNAfrati',
#  'b/FBonchi',
#  '63/3664',
#  'n/FrankNeven',
#  '92/6981',
#  '69/3405-1',
#  '80/6521',
#  'j/GabrielaJacquesSilva',
#  '72/7456',
#  '203/9710',
#  '67/6383-1',
#  '33/3180',
#  '29/2979',
#  '15/1669',
#  '07/1181',
#  '54/3265',
#  '49/6363',
#  '59/1952',
#  'f/GeorgeHLFletcher',
#  'k/GeorgeKollios',
#  '32/1624',
#  '44/2379',
#  'k/GeorgiaKoutrika',
#  '86/1747',
#  'w/GerhardWeikum',
#  '83/2426',
#  '86/1723',
#  'd/GDobbie',
#  '42/4419',
#  '151/8293',
#  '66/974',
#  'g/GoetzGraefe',
#  '69/1215-1',
#  'c/GVCormack',
#  'c/GrahamCormode',
#  '46/968',
#  '96/4724',
#  '51/1742',
#  'l/GuoliangLi',
#  '64/146',
#  '40/3179',
#  '159/9386',
#  'a/GustavoAlonso',
#  'j/HVJagadish',
#  '90/5236-1',
#  '120/7359',
#  '124/6911',
#  '75/6588-3',
#  '267/9406-2',
#  'w/HaixunWang',
#  'f/HFerhatosmanoglu',
#  '191/6085',
#  'k/HenryFKorth',
#  '25/9489',
#  '19/1082',
#  '23/1867',
#  '172/9415',
#  '24/279',
#  '184/2150',
#  '05/264',
#  'm/HeikoMuller',
#  '50/5895',
#  '237/4617',
#  '167/2106',
#  '26/5170',
#  '98/5721',
#  '149/2405',
#  '96/8522',
#  'g/HimanshuGupta',
#  '59/2081',
#  '08/3969',
#  '85/5637-1',
#  '91/6078',
#  '05/6545',
#  '81/940',
#  '04/10606',
#  'l/HuaLu',
#  '33/2952',
#  '13/8730',
#  'l/HuiLi5',
#  'x/HuiXiong',
#  '04/492',
#  'n/HungQNgo',
#  '77/6778',
#  '80/6889',
#  '45/1270',
#  '16/8981',
#  'i/IhabFIlyas',
#  'b/IlariaBartolini',
#  'p/IliaPetrov',
#  '85/9079',
#  'b/IndrajitBhattacharya',
#  'c/IngemarJCox',
#  '76/3160-2',
#  'm/IoanaManolescu',
#  '181/5758',
#  '83/741',
#  's/IonStoica',
#  'p/IppokratisPandis',
#  '194/2827',
#  'a/IraAssent',
#  '133/9910',
#  '74/6086',
#  'c/IFCruz',
#  '130/1705',
#  '135/3665',
#  '73/6460',
#  'h/JaakkoHollmen',
#  '21/4685',
#  '28/3904',
#  '61/3091',
#  '79/11278',
#  '96/3253',
#  '06/4171',
#  '249/2597',
#  '32/7263',
#  '06/9379',
#  '245/1850',
#  '40/2161',
#  '129/8181',
#  'p/JMPetit',
#  '222/9741',
#  'w/JefWijsen',
#  'n/JeffreyFNaughton',
#  'y/JXuYu',
#  '05/10671',
#  '43/2286',
#  'd/JensPeterDittrich',
#  't/JensTeubner',
#  '97/5585',
#  '25/6583',
#  '08/4537',
#  '02/146',
#  'l/JiahengLu',
#  'p/JianPei',
#  '51/2627',
#  '181/2667-5',
#  '30/9823',
#  '173/2707',
#  '64/1071-1',
#  '43/6576',
#  'x/JianliangXu',
#  '06/3456-1',
#  '39/7183',
#  'l/JianxinLi',
#  '181/9099',
#  '41/1074-1',
#  '89/9935',
#  '67/4834-4',
#  '84/2644',
#  '131/4047',
#  'w/JRWen',
#  '14/10827',
#  '27/229-2',
#  '132/7581',
#  '08/1790',
#  '96/8654',
#  '67/6415',
#  '174/0021',
#  '59/6952',
#  'f/JCFreytag',
#  'g/JohannesGehrke',
#  '63/9993',
#  '34/5936',
#  '95/9170',
#  '163/0545',
#  '52/6414',
#  '168/4993',
#  'g/JonathanGoldstein',
#  '09/6353',
#  '147/1195',
#  'f/JAFernandesdeMacedo',
#  'm/JFMartinez',
#  'd/JDomingoFerrer',
#  '39/5361',
#  'm/JosianeMothe',
#  '127/3025',
#  '78/4413',
#  's/JuliaStoyanovich',
#  '29/3483',
#  '82/9876',
#  'f/JulianaFreire',
#  '139/7506',
#  '82/4977-3',
#  '90/514-1',
#  'y/JunYang1',
#  '06/11411',
#  '70/2659',
#  '02/3658',
#  '150/7163',
#  '130/8167',
#  '37/10077',
#  '80/1651-2',
#  '73/3928-1',
#  '169/3246',
#  '127/6172-1',
#  '158/9207',
#  's/KaiUweSattler',
#  '140/7434',
#  '00/9080',
#  'k/KKarlapalem',
#  '42/4903',
#  '169/1501',
#  '230/0570',
#  'k/KarinKailing',
#  'z/KarineZeitouni',
#  'a/KarlAberer',
#  '51/792-2',
#  '99/2497',
#  'h/KatjaHose',
#  'w/KeWang',
#  '80/4136',
#  '43/1219-1',
#  '115/6264',
#  'b/KenBarker1',
#  'r/KARoss',
#  's/KennethSalem',
#  '56/10886',
#  'c/KCCChang',
#  '192/4560',
#  'd/KhuzaimaDaudjee',
#  't/KianLeeTan',
#  '117/4298',
#  '68/6119',
#  '151/6417',
#  '32/858',
#  '59/7992',
#  'c/LeiChen0002',
#  '81/3390-1',
#  '91/7584',
#  '38/4996',
#  'b/LEBertossi',
#  't/LetiziaTanca',
#  '39/3530-1',
#  '118/3677',
#  '01/5394-1',
#  '37/11078',
#  '68/5894',
#  '47/179',
#  '127/0779',
#  '74/3608-6',
#  '56/6651',
#  '21/10575',
#  '29/2701',
#  '141/4440',
#  '09/3737',
#  '27/3367-5',
#  '98/7136',
#  'r/LouiqaRaschid',
#  '69/157-1',
#  '51/5585',
#  'b/LucBouganim',
#  '60/7439',
#  '160/1741',
#  '180/3171',
#  'p/LucianPopa',
#  '80/468',
#  '201/1097',
#  '42/3296',
#  'd/XinLunaDong',
#  '81/10470',
#  'a/LyublenaAntova',
#  '200/8759',
#  'b/MagdalenaBalazinska',
#  '55/9613',
#  '87/8324',
#  '88/2433',
#  '23/282',
#  '25/7592',
#  '263/9205-1',
#  's/MonicaScannapieco',
#  '22/10701',
#  'g/ManishGupta1',
#  '210/0825',
#  '78/459-2',
#  '127/0162',
#  '90/1415',
#  '58/6066',
#  't/ManolisTerrovitis',
#  '82/7402',
#  '41/9728',
#  '185/1013',
#  '76/6735',
#  'b/MarcoBrambilla',
#  '89/6502',
#  '22/4732',
#  '87/6573',
#  't/MartinTheobald',
#  '09/7444',
#  'k/MasaruKitsuregawa',
#  'y/MasatoshiYoshikawa',
#  '36/2133',
#  'g/MatteoGolfarelli',
#  '49/10034',
#  '139/1128',
#  '206/0032',
#  '147/1263',
#  '75/887',
#  '82/1740',
#  'r/MatthiasRenz',
#  '61/267',
#  'l/MLatapy',
#  '46/8779',
#  '56/451',
#  '82/4386',
#  'c/MaxChevalier',
#  '77/3753',
#  '181/5823',
#  'r/MayaRamanath',
#  '96/4770',
#  '186/1469',
#  '71/11498',
#  '150/5229',
#  '71/9649',
#  '08/7259',
#  'w/MelanieWeis',
#  '69/339-1',
#  '14/8543',
#  '173/4598',
#  '93/9883',
#  'b/MichaelHBohlen',
#  '82/231',
#  '31/3455',
#  'f/MJFranklin',
#  '73/6114',
#  '10/5842',
#  '80/3560',
#  '20/9709',
#  '119/7671',
#  's/MichaelStonebraker',
#  '57/10355',
#  '78/8779',
#  '83/5342-6',
#  'l/MingLi6',
#  '20/2039-18',
#  '01/7213',
#  'g/MinosNGarofalakis',
#  'r/MirekRiedewald',
#  'm/MirellaMouraMoro',
#  '49/6395',
#  '94/5893',
#  '166/8411',
#  '95/9990',
#  's/MohamedASharaf',
#  '40/4987',
#  '01/4316-1',
#  '183/8663',
#  '56/7016',
#  '73/2496',
#  '46/2884',
#  '29/5841',
#  '20/9870',
#  '139/0871',
#  'o/MouradOuzzani',
#  '55/5690',
#  '42/904',
#  '11/6409',
#  '36/195',
#  '27/104-1',
#  '30/7183',
#  '17/2536',
#  '161/0113',
#  '23/3743',
#  't/NesimeTatbul',
#  '80/4976',
#  'k/NickKoudas',
#  '00/1107',
#  '119/0385',
#  '76/322',
#  '13/8165',
#  '188/9073',
#  '254/0972',
#  '76/3961',
#  '92/9686',
#  '58/1327',
#  '57/7247',
#  '17/1242',
#  '34/6253',
#  'n/NikosNtarmos',
#  '142/7802',
#  '03/545',
#  '52/6987',
#  'l/NinghuiLi',
#  '87/819-1',
#  '07/201-1',
#  '159/0466',
#  '12/1770-5',
#  '129/6927',
#  '83/9923',
#  '89/6071',
#  'p/NWPaton',
#  '124/3439',
#  '157/1134',
#  'p/OdysseasPapapetrou',
#  'h/OktieHassanzadeh',
#  '37/3024',
#  '71/7422',
#  '75/5478',
#  '53/7986',
#  '131/4377',
#  'm/PabitraMitra',
#  '74/5694',
#  '38/4801',
#  '08/5342',
#  '59/3814',
#  'a/PankajKAgarwal',
#  'c/PKChrysanthis',
#  '97/3036',
#  'a/PAtzeni',
#  'g/PaoloGarza',
#  '47/9855',
#  'm/PaoloMerialdo',
#  '28/1062',
#  'p/PaoloPapotti',
#  '49/8316',
#  '90/7704',
#  'g/ParkeGodfrey',
#  '80/8429',
#  '00/1996',
#  '66/8700',
#  '18/4350',
#  '76/185-3',
#  '21/1048-2',
#  '70/9686',
#  '52/1486',
#  '25/4106',
#  '47/8816',
#  'b/PeterABoncz',
#  'h/PeterJHaas',
#  '45/4887',
#  't/PeterTriantafillou',
#  'w/PeterTWood',
#  'b/PhilipABernstein',
#  '250/2789',
#  'b/PBonnet',
#  '71/5578',
#  '59/5146',
#  's/PSamarati',
#  'g/PGeneves',
#  '12/225',
#  's/PinarSenkul',
#  '86/9726',
#  '39/7035',
#  '198/5418',
#  '97/5147',
#  '133/3638',
#  '188/7008',
#  '188/6387',
#  '87/7541',
#  '145/6329',
#  '218/5887',
#  '128/2991',
#  '01/9014',
#  '194/4909',
#  '80/10462',
#  '58/1388',
#  '147/9053',
#  '181/2688-2',
#  '66/5923-8',
#  '79/3108',
#  '80/2732',
#  '61/3234',
#  '82/6362-1',
#  '20/9622',
#  '34/6522-1',
#  '45/47-1',
#  '181/2689-1',
#  '66/3005',
#  '169/1808',
#  'l/QiongLuo',
#  '50/4597',
#  '11/1466',
#  '68/1297',
#  '01/3589',
#  '205/9137',
#  '68/1677',
#  '48/10806',
#  's/RalfSchenkel',
#  '91/275',
#  '56/3378',
#  '245/6042',
#  '241/7225',
#  '131/4202',
#  '62/150',
#  '02/4973',
#  'w/RaymondChiWingWong',
#  '13/7406',
#  '147/1198',
#  '185/9964',
#  '36/10568',
#  'm/ReneMuller',
#  'm/RJMiller',
#  '137/9588',
#  '204/0158',
#  's/RenukaSindhgatta',
#  '89/2619',
#  '25/3618',
#  '169/8184',
#  't/RiccardoTorlone',
#  '75/3512',
#  '29/7184',
#  '121/4289',
#  '129/1674',
#  '96/7128',
#  '127/3163',
#  '79/1490',
#  '228/2573',
#  '37/548',
#  '23/1886',
#  '218/9188',
#  '51/5793',
#  '19/2405-1',
#  '03/505',
#  '178/8590',
#  '72/4662',
#  '203/8270',
#  '98/3414-1',
#  '175/1473',
#  '137/8445',
#  '17/5085',
#  's/SSudarshan1',
#  '74/9877',
#  '96/2418',
#  '26/101',
#  '90/2736',
#  '213/4131',
#  '30/1186',
#  '136/7969',
#  '168/0294',
#  '55/1967',
#  '22/835-1',
#  '98/7258',
#  '71/1647',
#  'm/SamuelMadden',
#  '11/7555',
#  '20/1055',
#  '139/2312',
#  'l/SangWonLee',
#  '147/1189',
#  '50/7626',
#  '92/6085',
#  '06/900-1',
#  'c/SaraCohen',
#  '57/10514',
#  '41/5564',
#  '38/768',
#  'w/XiaoyangSeanWang',
#  'g/SergioGreco',
#  '82/4089',
#  'g/SGhandeharizadeh',
#  '143/6186',
#  '94/2844',
#  '70/4688',
#  '149/1281',
#  '38/3523',
#  '83/2389-1',
#  '20/3883',
#  'm/SharadMehrotra',
#  's/ShashiShekhar',
#  '98/2324',
#  '85/7967',
#  '85/1868-11',
#  '85/1868',
#  '85/1868-7',
#  '217/7022',
#  'c/ShiminChen',
#  '35/3834',
#  '43/5188',
#  '131/9481',
#  '94/10440',
#  '21/5967',
#  '168/9023',
#  '96/3834',
#  '143/7236',
#  '124/7268',
#  '35/6569',
#  'c/ShuChingChen',
#  'b/SSBhowmick',
#  '127/0212',
#  '01/5237',
#  '65/5338',
#  '119/1402',
#  '76/1783',
#  '131/9628',
#  'b/SrikantaJBedathur',
#  '05/5881',
#  'b/SBressan',
#  'w/StevenEuijongWhang',
#  '28/3797',
#  'i/StratosIdreos',
#  '139/7927',
#  '190/1709',
#  '158/4862',
#  '77/4620',
#  '61/3197',
#  '21/5625',
#  '44/4775-2',
#  '71/5974',
#  '03/6702',
#  '46/1330',
#  '61/1573',
#  '93/5196',
#  '251/9524',
#  '204/3779',
#  '26/11046',
#  '19/5099',
#  '182/0250',
#  'c/SurajitChaudhuri',
#  'h/SvenHartmann',
#  'h/SvenHelmer',
#  '40/2808',
#  '38/4395',
#  '99/5856',
#  'o/MTamerOzsu',
#  '11/7631',
#  'm/TanuMalik',
#  '31/11538',
#  '179/2728',
#  '10/760',
#  '26/6037',
#  '73/2015',
#  's/TimosKSellis',
#  '19/2205',
#  '12/2633-6',
#  'y/TingYu',
#  '25/2228',
#  '56/7911',
#  '72/36',
#  '183/0983',
#  '69/159',
#  'c/ToonCalders',
#  'p/TorbenBachPedersen',
#  'g/TorstenGrust',
#  'a/TAmagasa',
#  'm/TovaMilo',
#  '05/1478',
#  '77/1703',
#  '166/7652',
#  '25/9994',
#  '07/1751',
#  '199/6350',
#  'c/UgurCetintemel',
#  'l/UlfLeser',
#  '99/6349',
#  'r/UweRohm',
#  '68/3004',
#  '67/6469',
#  '42/5855',
#  't/ValTannen',
#  'k/VanaKalogeraki',
#  '84/2055',
#  '51/10288',
#  '132/6943',
#  '87/11444',
#  'v/VVassalos',
#  '94/1028',
#  'c/VassilisChristophides',
#  '03/4045',
#  'c/VTChakaravarthy',
#  '156/1280',
#  'k/VerenaKantere',
#  '199/6298',
#  '151/5215',
#  '77/1485',
#  '06/8397',
#  'r/VijayshankarRaman',
#  '23/816',
#  '70/6404',
#  '80/594',
#  '10/11150',
#  '02/7933',
#  'o/VincentOria',
#  't/VincentSMTseng',
#  '88/995',
#  '162/6966',
#  '56/4585',
#  '83/7998',
#  'n/VivekRNarasayya',
#  'o/VivianeMoreiraOrengo',
#  'm/VMarkl',
#  '174/9539',
#  'm/WagnerMeiraJr',
#  '48/1707',
#  'a/WGAref',
#  '90/7457',
#  '172/0874',
#  '14/716',
#  't/WangChiewTan',
#  '149/9304',
#  'c/WeiChen1',
#  '89/2506-2',
#  '98/6613-15',
#  '35/7092-59',
#  'w/WeiWang9',
#  '35/7092-30',
#  'w/WeiWang11',
#  'w/WeiWang',
#  '28/10261-3',
#  '55/3364',
#  '45/8097',
#  '21/1694',
#  '30/841',
#  '49/8024',
#  '169/1390',
#  '68/11145',
#  'l/WLehner',
#  '146/6282',
#  '62/2450',
#  'h/WynneHsu',
#  '28/949-1',
#  '40/1491-33',
#  'l/XianLian',
#  '07/668-2',
#  '06/8315',
#  '126/6015',
#  'z/XiaofangZhou',
#  '83/4809-2',
#  '33/1903',
#  '117/4879-1',
#  '81/1832-2',
#  '47/3542-1',
#  '126/2338-1',
#  'y/XifengYan',
#  '130/1013',
#  '77/2970-1',
#  '98/5766-1',
#  '76/1820-20',
#  '10/5630-1',
#  '35/1895-1',
#  '52/8700',
#  '08/6809-1',
#  '19/189',
#  '152/8201',
#  '131/4767',
#  '19/3011',
#  '13/5407-5',
#  'l/LinXuemin',
#  '23/2460',
#  '127/0138',
#  '88/9060',
#  ...]

# %%
pid_name_mapping
# Out:
# {'75/9436': 'Aaron J. Elmore',
#  '162/9092': 'Abdalghani Abujabal',
#  '127/6195': 'Abdul Quamar',
#  '121/4198': 'Abdulhakim Ali Qahtan',
#  '116/1678': 'Abhijnan Chakraborty',
#  '39/1380': 'Abhishek Ghose',
#  '139/0855': 'Abhishek Kumar Singh',
#  '04/7892': 'Abolfazl Asudeh',
#  'j/AdamJatowt': 'Adam Jatowt',
#  '62/1373': 'Adam J. Lee',
#  '21/8510': 'Alexander Thomson',
#  '04/1835': 'Alexandra Meliou',
#  'l/ALabrinidis': 'Alexandros Labrinidis',
#  '92/2820': 'Alexandros Ntoulas',
#  'k/AlfonsKemper': 'Alfons Kemper',
#  '159/6520': 'Ali Ahmadvand',
#  'd/AlinDeutsch': 'Alin Deutsch',
#  '134/9031': 'Aline Bessa',
#  '164/1401': 'Alireza Heidari',
#  'p/NeoklisPolyzotis': 'Neoklis Polyzotis',
#  's/ASimitsis': 'Alkis Simitsis',
#  '163/3911': 'Allison Holloway',
#  'h/AlonYHalevy': 'Alon Y. Halevy',
#  's/ASdaSilva': 'Altigran Soares da Silva',
#  '16/4915': 'Alvin Cheung',
#  's/AmbujKSingh': 'Ambuj K. Singh',
#  '131/6619': 'Amelie Chi Zhou',
#  '136/7882': 'Amit Awekar',
#  '67/2583': 'Amit Gupta',
#  '77/5034': 'Amitabha Bagchi',
#  '75/5002': 'Amitava Das',
#  'd/AmolDeshpande': 'Amol Deshpande',
#  'a/AmrElAbbadi': 'Amr El Abbadi',
#  '05/8073-1': 'Amr Magdy 0001',
#  '160/4306': 'Amrith Krishna',
#  '127/1469': 'Amy Siu',
#  '37/10133-3': 'An Yan 0003',
#  '26/2579': 'Anand Mishra 0001',
#  'a/AnastassiaAilamaki': 'Anastasia Ailamaki',
#  'c/AndreaCali': 'Andrea Calì',
#  'h/AndreasHotho': 'Andreas Hotho',
#  '167/6469': 'Andreas Kipf',
#  '38/2946': 'Andreas Lommatzsch',
#  '18/2478': 'Andreas Züfle',
#  '222/3221': 'Andreea Deac',
#  '147/4971': 'Andrew Crotty',
#  '58/4127': 'Andrew Pavlo',
#  '218/6513': 'Andri Ashfahani',
#  'b/ABonifati': 'Angela Bonifati',
#  'd/AnHaiDoan': 'AnHai Doan',
#  'm/AnimeshMukherjee': 'Animesh Mukherjee 0001',
#  '73/2286': 'Anirban Chakraborty',
#  '54/385-1': 'Anirban Dasgupta 0001',
#  '81/10578': 'Anja Gruenheid',
#  '29/11192': 'Anna Fariha',
#  's/AnnaCinziaSquicciarini': 'Anna Cinzia Squicciarini',
#  '63/5512': 'Annalisa Appice',
#  '63/9828': 'Anshumali Shrivastava',
#  '147/1241': 'Anshuman Dutt',
#  't/AnthonyKHTung': 'Anthony K. H. Tung',
#  '96/11411': 'Anton Dignös',
#  'd/ADeligiannakis': 'Antonios Deligiannakis',
#  '163/0449': 'Aoqian Zhang',
#  'z/AoyingZhou': 'Aoying Zhou',
#  '183/5034': 'Aparna Garimella',
#  '20/3559': 'Aparna S. Varde',
#  'p/ANPapadopoulos': 'Apostolos N. Papadopoulos',
#  't/ArashTermehchy': 'Arash Termehchy',
#  'c/ALPChen': 'Arbee L. P. Chen',
#  '16/5085': 'Arijit Biswas',
#  '67/2933': 'Arijit Khan 0001',
#  '34/5594': 'Arindam Pal 0001',
#  'g/AristidesGionis': 'Aristides Gionis',
#  '19/2546': 'Arlei Silva',
#  '48/2626-1': 'Arnab Bhattacharya 0001',
#  '66/3027': 'Barna Saha',
#  '45/2495': 'Barzan Mozafari',
#  '83/11148': 'Batya Kenig',
#  '200/8321': 'Behrooz Omidvar-Tehrani',
#  '61/5238': 'Ben Carterette',
#  'k/BenKao': 'Ben Kao',
#  'o/BengChinOoi': 'Beng Chin Ooi',
#  '218/5225': 'Benjamin Hättasch',
#  '74/3195': 'Benny Kimelfeld',
#  '51/6689': 'Bernadette Farias Lóscio',
#  'a/BAmann': 'Bernd Amann',
#  'l/BertramLudascher': 'Bertram Ludäscher',
#  'k/BettinaKemme': 'Bettina Kemme',
#  '131/6284': 'Bikash Chandra',
#  'h/BillHowe': 'Bill Howe',
#  '55/5031': 'Bin Cui 0001',
#  '98/4432-3': 'Bin Wu 0003',
#  '77/377-2': 'Bin Yang 0002',
#  'h/BingshengHe': 'Bingsheng He',
#  '33/4411': 'Biplav Srivastava',
#  'k/BKonigRies': 'Birgitta König-Ries',
#  'j/BjornTorJonsson1': 'Björn Þór Jónsson 0001',
#  '50/3402-1': 'Bo Li 0001',
#  '26/1194-23': 'Bo Xu 0023',
#  '46/3522': 'Bolin Ding',
#  '152/4895': 'Bolong Zheng',
#  '20/6358': 'Bongki Moon',
#  '75/3108': 'Boon Thau Loo',
#  '09/3012': 'Boris Glavic',
#  '180/5761': 'Brandon Haynes',
#  '185/4349': 'Brit Youngmann',
#  '07/1560': 'Byron Choi',
#  'm/CMohan': 'C. Mohan 0001',
#  'j/CVJawahar': 'C. V. Jawahar',
#  't/CaetanoTrainaJr': 'Caetano Traina Jr.',
#  '74/20': 'Çagatay Demiralp',
#  '193/1652': 'Caihua Shan',
#  '149/1789': 'Can Lu',
#  'c/CarloCurino': 'Carlo Curino',
#  '17/5910': 'Carlos Scheidegger',
#  '26/3914': 'Carmem S. Hara',
#  'r/CarolinaRuiz': 'Carolina Ruiz',
#  '45/1559': 'Carsten Binnig',
#  '28/10108': 'Catarina Moreira',
#  '97/919-1': 'Ce Zhang 0001',
#  '122/5424-2': 'Chang Ge 0002',
#  '08/4367': 'Chang-Tien Lu',
#  '170/5430': 'Chanyoung Park',
#  '18/4087-1': 'Chao Huang 0001',
#  '94/3019-45': 'Chao Zhang 0045',
#  '13/1672': 'Chaokun Wang',
#  'c/CheeYongChan': 'Chee Yong Chan',
#  'l/ChenLi1': 'Chen Li 0001',
#  '92/2769': 'Luo Chen',
#  '82/4206-11': 'Chen Wang 0011',
#  '33/11343': 'Xiuying Chen',
#  '58/10813': 'Cheng Long',
#  '49/1457-2': 'Cheng Yang 0002',
#  'l/ChengfeiLiu': 'Chengfei Liu',
#  '51/3529-1': 'Chenggang Wu 0001',
#  '14/3692': 'Chengkai Li',
#  '52/9457': 'Chenliang Li',
#  '18/10886': 'Chenyan Xiong',
#  '09/404-1': 'Chi Wang 0001',
#  '38/8845': 'Chih-Ya Shen',
#  'r/ChinyaVRavishankar': 'Chinya V. Ravishankar',
#  'b/CBhattacharyya': 'Chiranjib Bhattacharyya',
#  '198/4308': "Choiru Za'in",
#  'j/ChrisJermaine': 'Chris Jermaine',
#  'b/ChristianBizer': 'Christian Bizer',
#  'j/ChristianSJensen': 'Christian S. Jensen',
#  'k/ChristophKoch': 'Christoph Koch 0001',
#  '154/6336': 'Christopher De Sa',
#  'r/ChristopherRe': 'Christopher Ré',
#  '87/10957': 'Chuan Lei',
#  '64/3041': 'Chuan Shi',
#  '57/4384-1': 'Chuan Xiao 0001',
#  '20/1969-1': 'Chun Ouyang 0001',
#  '82/11411': 'Chunbin Lin',
#  '65/3446': 'Claudia Plant',
#  '58/3771': 'Cong Yu 0001',
#  '116/0694': 'Constantinos Costa',
#  '69/6680': 'Cornelia Caragea',
#  'd/CEDyreson': 'Curtis E. Dyreson',
#  's/CyrusShahabi': 'Cyrus Shahabi',
#  '81/9436-1': 'Da Yan 0001',
#  '223/3148': 'Daheng Wang',
#  '27/2143': 'Daisy Zhe Wang',
#  '84/114': 'Daniel Kifer',
#  '03/6105': 'Dan R. K. Ports',
#  's/DanSuciu': 'Dan Suciu',
#  '154/0932': 'Dana Van Aken',
#  'y/DanfengYao': 'Danfeng Yao',
#  '69/9726': 'Danica Porobic',
#  'a/DJAbadi': 'Daniel J. Abadi',
#  '98/6876': 'Daniel Deutch',
#  '40/6300': 'Daniel Kang',
#  '68/7553-1': 'Daniel de Oliveira 0001',
#  '93/9012': 'Danish Contractor',
#  '133/1954': 'Daojian Zeng',
#  'c/DarioColazzo': 'Dario Colazzo',
#  '54/1720': 'David Koop',
#  '14/6896': 'Davide Martinenghi',
#  '135/7623': 'Davide Mottin',
#  'r/DRafiei': 'Davood Rafiei',
#  'm/DebapriyoMajumdar': 'Debapriyo Majumdar',
#  '41/7272': 'Debasis Ganguly',
#  '65/6758': 'Deepak Mishra',
#  '33/1882': 'Deepak P 0001',
#  'z/DemetriosZeinalipourYazti': 'Demetrios Zeinalipour-Yazti',
#  '85/318': 'De-Nian Yang',
#  'b/DBarbosa': 'Denilson Barbosa',
#  '83/8652': 'Di You',
#  '82/2760': 'Dimitrios Georgakopoulos',
#  'g/DimitriosGunopulos': 'Dimitrios Gunopulos',
#  'p/DimitrisPapadias': 'Dimitris Papadias',
#  '19/4428': 'Dimitris Sacharidis',
#  '94/4438': 'Dinesh Garg',
#  '81/6181': 'Dingming Wu 0001',
#  '43/6688': 'Dipyaman Banerjee',
#  's/DiveshSrivastava': 'Divesh Srivastava',
#  'a/DivyakantAgrawal': 'Divyakant Agrawal',
#  '161/0102': 'Divya Mahajan',
#  '155/5478': 'Dixin Tang',
#  '70/11145': 'Diyi Yang',
#  '09/10814': 'Djellel Eddine Difallah',
#  '147/1186': 'Dominik Moritz',
#  'k/DonaldKossmann': 'Donald Kossmann',
#  '05/10127': 'Donatella Firmani',
#  '71/8700-1': 'Dong Deng 0001',
#  '20/6977-1': 'Dong Xie 0001',
#  '33/6749': 'Donghyun Kim',
#  '89/6013': 'Dongxiang Zhang',
#  '03/10118': 'Dumitrel Loghin',
#  '37/640': 'Durga Toshniwal',
#  '151/2098': 'Dwaipayan Roy',
#  '78/5231': 'Eddie Kohler',
#  '66/6919': 'Eduard C. Dragut',
#  '24/788': 'Eduardo S. Ogasawara',
#  'f/EdwardAFox': 'Edward A. Fox',
#  '04/1538': 'Edwin Lughofer',
#  '68/3366': 'Ekaterini Ioannou',
#  '77/5283': 'Elena Baralis',
#  '84/2154': 'Elena Demidova',
#  'f/ElenaFerrari': 'Elena Ferrari',
#  '164/7451': 'Eleni Tzirita Zacharatou',
#  '225/2019': 'Eliana Pastor',
#  'b/ElisaBertino': 'Elisa Bertino',
#  'r/EARundensteiner': 'Elke A. Rundensteiner',
#  '96/8919': 'El Kindi Rezig',
#  '55/6899': 'Emmanuel Müller',
#  '31/9364': 'Entong Shen',
#  'r/ERahm': 'Erhard Rahm',
#  '80/2320': 'Eric Lo 0001',
#  '88/6520': 'Erietta Liarou',
#  '116/5135': 'Erkang Zhu',
#  '54/6752': 'Eser Kandogan',
#  'm/EssamMansour': 'Essam Mansour',
#  '177/8852': 'Ester Livshits',
#  '41/3679': 'Eugene Wu 0002',
#  '81/4388': 'Eunyee Koh',
#  'p/EPitoura': 'Evaggelia Pitoura',
#  '21/3626-36': 'Fan Zhang 0036',
#  '34/508': 'Farnoush Banaei Kashani',
#  't/FaroukToumani': 'Farouk Toumani',
#  '23/7274': 'Fatemeh Nargesian',
#  'o/FatmaOzcan': 'Fatma Özcan',
#  '66/2556': 'Fei Chiang',
#  '51/394-1': 'Fei Sun 0001',
#  '84/3254-5': 'Fei Wu 0005',
#  '77/1985': 'Feida Zhu 0001',
#  'l/FeifeiLi': 'Feifei Li 0001',
#  'n/FelixNaumann': 'Felix Naumann',
#  '129/6818': 'Felix Martin Schuhknecht',
#  '48/1294-7': 'Feng Zhang 0007',
#  '04/5404': 'Fernando Seabra Chirigati',
#  '167/4770': 'Filip Ilievski',
#  '14/4251': 'Filip Murlak',
#  'k/FlipKorn': 'Flip Korn',
#  '284/0968': 'Florian Hahn 0004',
#  '26/5304': 'Florian Kerschbaum',
#  '73/343': 'Florin Rusu',
#  'g/FlorisGeerts': 'Floris Geerts',
#  '135/5141': 'Fotis Psallidas',
#  'a/FotoNAfrati': 'Foto N. Afrati',
#  'b/FBonchi': 'Francesco Bonchi',
#  '63/3664': 'Francesco Gullo',
#  'n/FrankNeven': 'Frank Neven',
#  '92/6981': 'François Goasdoué',
#  '69/3405-1': 'Fusheng Wang 0001',
#  '80/6521': 'Gabriel Ghinita',
#  'j/GabrielaJacquesSilva': 'Gabriela Jacques-Silva',
#  '72/7456': 'Gabriele Tolomei',
#  '203/9710': 'Ganesh Jawahar',
#  '67/6383-1': 'Gang Chen 0001',
#  '33/3180': 'Gao Cong',
#  '29/2979': 'Gaurav Sinha',
#  '15/1669': 'Gaurav Verma',
#  '07/1181': 'Gautam Das 0001',
#  '54/3265': 'Gautam Shroff',
#  '49/6363': 'Ge Yu 0001',
#  '59/1952': 'Georgios John Fakas',
#  'f/GeorgeHLFletcher': 'George Fletcher 0001',
#  'k/GeorgeKollios': 'George Kollios',
#  '32/1624': 'George Papadakis 0001',
#  '44/2379': 'George Papastefanatos',
#  'k/GeorgiaKoutrika': 'Georgia Koutrika',
#  '86/1747': 'Gerard de Melo',
#  'w/GerhardWeikum': 'Gerhard Weikum',
#  '83/2426': 'Germain Forestier',
#  '86/1723': 'Ghislain Fourny',
#  'd/GDobbie': 'Gillian Dobbie',
#  '42/4419': 'Giorgos Giannopoulos',
#  '151/8293': 'Giovanni Simonini',
#  '66/974': 'Goce Trajcevski',
#  'g/GoetzGraefe': 'Goetz Graefe',
#  '69/1215-1': 'Gong Cheng 0001',
#  'c/GVCormack': 'Gordon V. Cormack',
#  'c/GrahamCormode': 'Graham Cormode',
#  '46/968': 'Gregory Grefenstette',
#  '96/4724': 'Grigorios Loukides',
#  '51/1742': 'Guihai Chen',
#  'l/GuoliangLi': 'Guoliang Li 0001',
#  '64/146': 'Guoren Wang',
#  '40/3179': 'Guozhang Wang',
#  '159/9386': 'Utkarsh Gupta',
#  'a/GustavoAlonso': 'Gustavo Alonso',
#  'j/HVJagadish': 'H. V. Jagadish',
#  '90/5236-1': 'Haibo Hu 0001',
#  '120/7359': 'Hainan Zhang',
#  '124/6911': 'Haipeng Dai',
#  '75/6588-3': 'Haitao Yu 0003',
#  '267/9406-2': 'Haitao Yuan 0002',
#  'w/HaixunWang': 'Haixun Wang',
#  'f/HFerhatosmanoglu': 'Hakan Ferhatosmanoglu',
#  '191/6085': 'Hamed Khanpour',
#  'k/HenryFKorth': 'Henry F. Korth',
#  '25/9489': 'Hannes Mühleisen',
#  '19/1082': 'Hannes Voigt',
#  '23/1867': 'Wei Hao',
#  '172/9415': 'Haoyu Huang',
#  '24/279': 'Haridimos Kondylakis',
#  '184/2150': 'Harika Abburi',
#  '05/264': 'Harish Doraiswamy',
#  'm/HeikoMuller': 'Heiko Müller 0001',
#  '50/5895': 'Heiner Stuckenschmidt',
#  '237/4617': 'Heli Helskyaho',
#  '167/2106': 'Hemant Saxena',
#  '26/5170': 'Herodotos Herodotou',
#  '149/2405': 'Hima Patel',
#  '96/8522': 'Himanshu S. Bhatt',
#  'g/HimanshuGupta': 'Himanshu Gupta',
#  '59/2081': 'Hiroshi Mamitsuka',
#  '08/3969': 'Holger Pirk',
#  '85/5637-1': 'Hong Cheng 0001',
#  '91/6078': 'Hong-Jie Dai',
#  '05/6545': 'Hongning Wang',
#  '81/940': 'Hongzhi Wang 0001',
#  '04/10606': 'Hongzhi Yin',
#  'l/HuaLu': 'Hua Lu 0001',
#  '33/2952': 'Huan Sun',
#  '13/8730': 'Huanchen Zhang',
#  'l/HuiLi5': 'Hui Li 0005',
#  'x/HuiXiong': 'Hui Xiong 0001',
#  '04/492': 'Huiping Cao',
#  'n/HungQNgo': 'Hung Q. Ngo 0001',
#  '77/6778': 'Huy T. Vo',
#  '80/6889': 'Hwanjo Yu',
#  '45/1270': 'Hyungsoo Jung',
#  '16/8981': 'Ibrahim Sabek',
#  'i/IhabFIlyas': 'Ihab F. Ilyas',
#  'b/IlariaBartolini': 'Ilaria Bartolini',
#  'p/IliaPetrov': 'Ilia Petrov',
#  '85/9079': 'Immanuel Trummer',
#  'b/IndrajitBhattacharya': 'Indrajit Bhattacharya',
#  'c/IngemarJCox': 'Ingemar J. Cox',
#  '76/3160-2': 'Ingo Müller 0002',
#  'm/IoanaManolescu': 'Ioana Manolescu',
#  '181/5758': 'Ioannis Demertzis',
#  '83/741': 'Ioannis Konstantinou',
#  's/IonStoica': 'Ion Stoica',
#  'p/IppokratisPandis': 'Ippokratis Pandis',
#  '194/2827': 'Iqra Altaf Gillani',
#  'a/IraAssent': 'Ira Assent',
#  '133/9910': 'Iraklis Psaroudakis',
#  '74/6086': 'Irini Fundulaki',
#  'c/IFCruz': 'Isabel F. Cruz',
#  '130/1705': 'Isak Karlsson',
#  '135/3665': 'Ismail Oukid',
#  '73/6460': 'Iulian Sandu Popa',
#  'h/JaakkoHollmen': 'Jaakko Hollmén',
#  '21/4685': 'Jae W. Lee',
#  '28/3904': 'Jae-Gil Lee 0001',
#  '61/3091': 'Jaideep Vaidya',
#  '79/11278': 'James B. Wendt',
#  '96/3253': 'James Cheney',
#  '06/4171': 'James Cheng',
#  '249/2597': 'Jan Tönshoff',
#  '32/7263': 'Jana Giceva',
#  '06/9379': 'Jaroslaw Szlichta',
#  '245/1850': 'Jason Ingyu Choi',
#  '40/2161': 'Javier Parapar',
#  '129/8181': 'Jaydeep Sen',
#  'p/JMPetit': 'Jean-Marc Petit',
#  '222/9741': 'Jees Augustine',
#  'w/JefWijsen': 'Jef Wijsen',
#  'n/JeffreyFNaughton': 'Jeffrey F. Naughton',
#  'y/JXuYu': 'Jeffrey Xu Yu',
#  '05/10671': 'Jelle Hellings',
#  '43/2286': 'Jennie Rogers',
#  'd/JensPeterDittrich': 'Jens Dittrich',
#  't/JensTeubner': 'Jens Teubner',
#  '97/5585': 'Jeong-Hyon Hwang',
#  '25/6583': 'Jeremy Kepner',
#  '08/4537': 'Jia Zou 0001',
#  '02/146': 'Jiafeng Guo',
#  'l/JiahengLu': 'Jiaheng Lu',
#  'p/JianPei': 'Jian Pei',
#  '51/2627': 'Jian Tan',
#  '181/2667-5': 'Jian Tang 0005',
#  '30/9823': 'Jianfei Yu',
#  '173/2707': 'Jianglei Han',
#  '64/1071-1': 'Jianguo Wang 0001',
#  '43/6576': 'Jianhua Feng',
#  'x/JianliangXu': 'Jianliang Xu',
#  '06/3456-1': 'Jianmin Wang 0001',
#  '39/7183': 'Jiannan Wang',
#  'l/JianxinLi': 'Jianxin Li 0001',
#  '181/9099': 'Jianye Yang',
#  '41/1074-1': 'Jianzhong Qi 0001',
#  '89/9935': 'Jinfei Liu',
#  '67/4834-4': 'Jing Gao 0004',
#  '84/2644': 'Jingren Zhou',
#  '131/4047': 'Jinyang Gao',
#  'w/JRWen': 'Ji-Rong Wen',
#  '14/10827': 'Jithin Vachery',
#  '27/229-2': 'Jiwon Seo 0002',
#  '132/7581': 'Jiyun Luo',
#  '08/1790': 'João Magalhães',
#  '96/8654': 'João R. M. Palotti',
#  '67/6415': 'Jochen L. Leidner',
#  '174/0021': 'Joel Mackenzie',
#  '59/6952': 'Johann Gamper',
#  'f/JCFreytag': 'Johann-Christoph Freytag',
#  'g/JohannesGehrke': 'Johannes Gehrke',
#  '63/9993': 'John Boaz Lee',
#  '34/5936': 'John Krumm',
#  '95/9170': 'John Liagouris',
#  '163/0545': 'John Paparrizos',
#  '52/6414': 'Paul Johns',
#  '168/4993': 'Jonas Traub',
#  'g/JonathanGoldstein': 'Jonathan Goldstein',
#  '09/6353': 'Jorge-Arnulfo Quiané-Ruiz',
#  '147/1195': 'Jose M. Faleiro',
#  'f/JAFernandesdeMacedo': 'José A. F. de Macêdo',
#  'm/JFMartinez': 'José F. Martínez',
#  'd/JDomingoFerrer': 'Josep Domingo-Ferrer',
#  '39/5361': 'Joseph P. Near',
#  'm/JosianeMothe': 'Josiane Mothe',
#  '127/3025': 'Joy Arulraj',
#  '78/4413': 'Ju Fan',
#  's/JuliaStoyanovich': 'Julia Stoyanovich',
#  '29/3483': 'Julian J. McAuley',
#  '82/9876': 'Julian Shun',
#  'f/JulianaFreire': 'Juliana Freire',
#  '139/7506': 'Julian Romero',
#  '82/4977-3': 'Jun Gao 0003',
#  '90/514-1': 'Jun Xu 0001',
#  'y/JunYang1': 'Jun Yang 0001',
#  '06/11411': 'Junhao Gan',
#  '70/2659': 'Junhu Wang',
#  '02/3658': 'Justin J. Levandoski',
#  '150/7163': 'Jyoti Leeka',
#  '130/8167': 'Jyun-Yu Jiang',
#  '37/10077': 'Kai Hui',
#  '80/1651-2': 'Kai Zeng 0002',
#  '73/3928-1': 'Kai Zheng 0001',
#  '169/3246': 'Kaiping Zheng',
#  '127/6172-1': 'Kaiqi Zhao 0001',
#  '158/9207': 'Kaiqun Fu',
#  's/KaiUweSattler': 'Kai-Uwe Sattler',
#  '140/7434': 'Kaiyu Feng',
#  '00/9080': 'Kalpa Gunaratna',
#  'k/KKarlapalem': 'Kamalakar Karlapalem',
#  '42/4903': 'Kang Liu 0001',
#  '169/1501': 'Kangfei Zhao',
#  '230/0570': 'Karima Echihabi',
#  'k/KarinKailing': 'Karin Murthy',
#  'z/KarineZeitouni': 'Karine Zeitouni',
#  'a/KarlAberer': 'Karl Aberer',
#  '51/792-2': 'Karthik Ramachandra 0002',
#  '99/2497': 'Kartik Talamadupula',
#  'h/KatjaHose': 'Katja Hose',
#  'w/KeWang': 'Ke Wang 0001',
#  '80/4136': 'Ke Yang',
#  '43/1219-1': 'Ke Yi 0001',
#  '115/6264': 'Kedar Kulkarni',
#  'b/KenBarker1': 'Ken Barker 0001',
#  'r/KARoss': 'Kenneth A. Ross',
#  's/KennethSalem': 'Kenneth Salem',
#  '56/10886': 'Keping Bi',
#  'c/KCCChang': 'Kevin Chen-Chuan Chang',
#  '192/4560': 'Kexin Rong',
#  'd/KhuzaimaDaudjee': 'Khuzaima Daudjee',
#  't/KianLeeTan': 'Kian-Lee Tan',
#  '117/4298': 'Venkata Rama Kiran Garimella',
#  '68/6119': 'Kok-Leong Ong',
#  '151/6417': 'Koninika Pal',
#  '32/858': 'Konstantinos Chatzikokolakis 0001',
#  '59/7992': 'Konstantinos Karanasos',
#  'c/LeiChen0002': 'Lei Chen 0002',
#  '81/3390-1': 'Lei Zou 0001',
#  '91/7584': 'Leilani Battle',
#  '38/4996': 'Leong Hou U',
#  'b/LEBertossi': 'Leopoldo E. Bertossi',
#  't/LetiziaTanca': 'Letizia Tanca',
#  '39/3530-1': 'Li Xiong 0001',
#  '118/3677': 'Liana Ermakova',
#  '01/5394-1': 'Liang Chen 0001',
#  '37/11078': 'Liang Pang',
#  '68/5894': 'Liang-Chih Yu',
#  '47/179': 'Lijun Chang',
#  '127/0779': 'Lili Mou',
#  '74/3608-6': 'Lin Ma 0006',
#  '56/6651': 'Lina Yao',
#  '21/10575': 'Lingyang Chu',
#  '29/2701': 'Lini T. Thomas',
#  '141/4440': 'Linmei Hu',
#  '09/3737': 'Lipika Dey',
#  '27/3367-5': 'Liu Yang 0005',
#  '98/7136': 'Lorraine Goeuriot',
#  'r/LouiqaRaschid': 'Louiqa Raschid',
#  '69/157-1': 'Lu Chen 0001',
#  '51/5585': 'Lu Qin 0001',
#  'b/LucBouganim': 'Luc Bouganim',
#  '60/7439': 'Luca Cagliero',
#  '160/1741': 'Luca Soldaini',
#  '180/3171': 'Lucas Lersch',
#  'p/LucianPopa': 'Lucian Popa 0001',
#  '80/468': 'Luciano Barbosa',
#  '201/1097': 'Luis Espinosa',
#  '42/3296': 'Lukasz Golab',
#  'd/XinLunaDong': 'Xin Dong 0001',
#  '81/10470': 'Luo Mai',
#  'a/LyublenaAntova': 'Lyublena Antova',
#  '200/8759': 'Madhulika Mohanty',
#  'b/MagdalenaBalazinska': 'Magdalena Balazinska',
#  '55/9613': 'Mahardhika Pratama',
#  '87/8324': 'Mainack Mondal',
#  '88/2433': 'Mamoru Komachi',
#  '23/282': 'Man Lung Yiu',
#  '25/7592': 'Manasi Vartak',
#  '263/9205-1': 'Maneesh Kumar Singh 0001',
#  's/MonicaScannapieco': 'Monica Scannapieco',
#  '22/10701': 'Manik Gupta',
#  'g/ManishGupta1': 'Manish Gupta 0001',
#  '210/0825': 'Manish Kesarwani',
#  '78/459-2': 'Manish Singh 0002',
#  '127/0162': 'Manjira Sinha',
#  '90/1415': 'Manoj K. Agarwal',
#  '58/6066': 'Manoj Kumar Chinnakotla',
#  't/ManolisTerrovitis': 'Manolis Terrovitis',
#  '82/7402': 'Manos Athanassoulis',
#  '41/9728': 'Manos Karpathiotakis',
#  '185/1013': 'Manuel R. Ciosici',
#  '76/6735': 'Marcelo Arenas',
#  'b/MarcoBrambilla': 'Marco Brambilla 0001',
#  '89/6502': 'Markus Weimer',
#  '22/4732': 'Martin Atzmüller',
#  '87/6573': 'Martin Potthast',
#  't/MartinTheobald': 'Martin Theobald',
#  '09/7444': 'Marwan Hassani',
#  'k/MasaruKitsuregawa': 'Masaru Kitsuregawa',
#  'y/MasatoshiYoshikawa': 'Masatoshi Yoshikawa',
#  '36/2133': 'Matei Zaharia',
#  'g/MatteoGolfarelli': 'Matteo Golfarelli',
#  '49/10034': 'Matteo Interlandi',
#  '139/1128': 'Matteo Lissandrini',
#  '206/0032': 'Matteo Paganelli',
#  '147/1263': 'Matthaios Olma',
#  '75/887': 'Matthias Boehm 0001',
#  '82/1740': 'Matthias Brantner',
#  'r/MatthiasRenz': 'Matthias Renz',
#  '61/267': 'Matthias Weidlich',
#  'l/MLatapy': 'Matthieu Latapy',
#  '46/8779': 'Maunendra Sankar Desarkar',
#  '56/451': 'Mauricio A. Hernández',
#  '82/4386': 'Mauro Conti',
#  'c/MaxChevalier': 'Max Chevalier',
#  '77/3753': 'Max Heimel',
#  '181/5823': 'Maximilian Schleich',
#  'r/MayaRamanath': 'Maya Ramanath',
#  '96/4770': 'Mayank Singh 0001',
#  '186/1469': 'Mayukh Das',
#  '71/11498': 'Mayuresh Kunjir',
#  '150/5229': 'Md Zia Ullah',
#  '71/9649': 'Megha Khosla',
#  '08/7259': 'Meihui Zhang 0001',
#  'w/MelanieWeis': 'Melanie Herschel',
#  '69/339-1': 'Meng Jiang 0001',
#  '14/8543': 'Meng Qu',
#  '173/4598': 'Mengting Wan',
#  '93/9883': 'Miao Qiao',
#  'b/MichaelHBohlen': 'Michael H. Böhlen',
#  '82/231': 'Michael J. Cafarella',
#  '31/3455': 'Michael J. Carey 0001',
#  'f/MJFranklin': 'Michael J. Franklin',
#  '73/6114': 'Michael Grossniklaus',
#  '10/5842': 'Michael N. Gubanov',
#  '80/3560': 'Michael Mathioudakis',
#  '20/9709': 'Michael J. Mior',
#  '119/7671': 'Michaela Hardt',
#  's/MichaelStonebraker': 'Michael Stonebraker',
#  '57/10355': 'Milos Nikolic',
#  '78/8779': 'Min Xie 0002',
#  '83/5342-6': 'Min Zhang 0006',
#  'l/MingLi6': 'Ming Li 0006',
#  '20/2039-18': 'Ming Liu 0018',
#  '01/7213': 'MingJie Tang',
#  'g/MinosNGarofalakis': 'Minos N. Garofalakis',
#  'r/MirekRiedewald': 'Mirek Riedewald',
#  'm/MirellaMouraMoro': 'Mirella M. Moro',
#  '49/6395': 'Mohamed Y. Eltabakh',
#  '94/5893': 'Mohamed F. Mokbel',
#  '166/8411': 'Mohamed S. Hassan',
#  '95/9990': 'Mohamed Sarwat',
#  's/MohamedASharaf': 'Mohamed A. Sharaf',
#  '40/4987': 'Mohamed Soliman',
#  '01/4316-1': 'Mohammad Dashti 0001',
#  '183/8663': 'Mohammad Javad Amiri',
#  '56/7016': 'Mohammad Sadoghi',
#  '73/2496': 'Mohammad S. Sorower',
#  '46/2884': 'Mohammed Eunus Ali',
#  '29/5841': 'Monojit Choudhury',
#  '20/9870': 'Morakot Choetkiertikul',
#  '139/0871': 'Mostafa Milani',
#  'o/MouradOuzzani': 'Mourad Ouzzani',
#  '55/5690': 'Muhammad Aamir Cheema',
#  '42/904': 'Muhammad Abulaish',
#  '11/6409': 'Murat Demirbas',
#  '36/195': 'Murat Kantarcioglu',
#  '27/104-1': 'Nan Tang 0001',
#  '30/7183': 'Narayanan Unny Edakunni',
#  '17/2536': 'Naresh Manwani',
#  '161/0113': 'Natacha Crooks',
#  '23/3743': 'Natwar Modani',
#  't/NesimeTatbul': 'Nesime Tatbul',
#  '80/4976': 'Nga Tran',
#  'k/NickKoudas': 'Nick Koudas',
#  '00/1107': 'Nicolas Anciaux',
#  '119/0385': 'Niharika Sachdeva',
#  '76/322': 'Nikesh Garera',
#  '13/8165': 'Niketan Pansare',
#  '188/9073': 'Nikita Bhutani',
#  '254/0972': 'Nikolaos Tziavelis',
#  '76/3961': 'Nikolaus Augsten',
#  '92/9686': 'Nikolay Yakovets',
#  '58/1327': 'Nikos Armenatzoglou',
#  '57/7247': 'Nikos Bikakis',
#  '17/1242': 'Nikos Giatrakos',
#  '34/6253': 'Nikos Mamoulis',
#  'n/NikosNtarmos': 'Nikos Ntarmos',
#  '142/7802': 'Nikos R. Katsipoulakis',
#  '03/545': 'Niladri Chatterjee',
#  '52/6987': 'Niloy Ganguly',
#  'l/NinghuiLi': 'Ninghui Li',
#  '87/819-1': 'Niraj Kumar 0001',
#  '07/201-1': 'Nishant Sinha 0001',
#  '159/0466': 'Nishtha Madaan',
#  '12/1770-5': 'Nitin Gupta 0005',
#  '129/6927': 'Niv Dayan',
#  '83/9923': 'Niyati Chhaya',
#  '89/6071': 'Norman May',
#  'p/NWPaton': 'Norman W. Paton',
#  '124/3439': 'Nur Al Hasan Haldar',
#  '157/1134': 'Oana Balmau',
#  'p/OdysseasPapapetrou': 'Odysseas Papapetrou',
#  'h/OktieHassanzadeh': 'Oktie Hassanzadeh',
#  '37/3024': 'Olga Papaemmanouil',
#  '71/7422': 'Olga Poppe',
#  '75/5478': 'Oliver Kennedy',
#  '53/7986': 'Omar Chowdhury',
#  '131/4377': 'Orestis Polychroniou',
#  'm/PabitraMitra': 'Pabitra Mitra',
#  '74/5694': 'Pan Du',
#  '38/4801': 'Panagiotis Bouros',
#  '08/5342': 'Panagiotis Karras',
#  '59/3814': 'Panagiotis Papapetrou',
#  'a/PankajKAgarwal': 'Pankaj K. Agarwal',
#  'c/PKChrysanthis': 'Panos K. Chrysanthis',
#  '97/3036': 'Panos Kalnis',
#  'a/PAtzeni': 'Paolo Atzeni',
#  'g/PaoloGarza': 'Paolo Garza',
#  '47/9855': 'Paolo Guagliardo',
#  'm/PaoloMerialdo': 'Paolo Merialdo',
#  '28/1062': 'Paolo Missier',
#  'p/PaoloPapotti': 'Paolo Papotti',
#  '49/8316': 'Paraschos Koutris',
#  '90/7704': 'Paris Carbone',
#  'g/ParkeGodfrey': 'Parke Godfrey',
#  '80/8429': 'Parth Gupta',
#  '00/1996': 'Peifeng Li',
#  '66/8700': 'Peifeng Yin',
#  '18/4350': 'Peixiang Zhao',
#  '76/185-3': 'Peng Cheng 0003',
#  '21/1048-2': 'Peng Zhang 0002',
#  '70/9686': 'Pengfei Duan',
#  '52/1486': 'Periklis Andritsos',
#  '25/4106': 'Peter Alvaro',
#  '47/8816': 'Peter Bailis',
#  'b/PeterABoncz': 'Peter A. Boncz',
#  'h/PeterJHaas': 'Peter J. Haas',
#  '45/4887': 'Peter R. Pietzuch',
#  't/PeterTriantafillou': 'Peter Triantafillou',
#  'w/PeterTWood': 'Peter T. Wood',
#  'b/PhilipABernstein': 'Philip A. Bernstein',
#  '250/2789': 'Philipp Christmann',
#  'b/PBonnet': 'Philippe Bonnet',
#  '71/5578': 'Philippe Cudré-Mauroux',
#  '59/5146': 'Philippe Lamarre',
#  's/PSamarati': 'Pierangela Samarati',
#  'g/PGeneves': 'Pierre Genevès',
#  '12/225': 'Pierre Senellart',
#  's/PinarSenkul': 'Pinar Karagöz',
#  '86/9726': 'Pinar Tözün',
#  '39/7035': 'Ping Lu',
#  '198/5418': 'Pinkesh Badjatiya',
#  '97/5147': 'Ponnurangam Kumaraguru',
#  '133/3638': 'Pooja Aggarwal',
#  '188/7008': 'Pranav Maneriker',
#  '188/6387': 'Pranay Lohia',
#  '87/7541': 'Prasant Misra',
#  '145/6329': 'Prashanth Menon',
#  '218/5887': 'Prathosh A. P.',
#  '128/2991': 'Pratibha Moogi',
#  '01/9014': 'Preethi Jyothi',
#  '194/4909': 'Prerna Agarwal',
#  '80/10462': 'Prithu Banerjee',
#  '58/1388': 'Prithviraj Sen',
#  '147/9053': 'Priya Radhakrishnan',
#  '181/2688-2': 'Qi Li 0002',
#  '66/5923-8': 'Qi Zhu 0008',
#  '79/3108': 'Qian Lin',
#  '80/2732': 'Qiang Huang',
#  '61/3234': 'Qiang Liu',
#  '82/6362-1': 'Qiang Yang 0001',
#  '20/9622': 'Qiang Yin',
#  '34/6522-1': 'Qiang Zhu 0001',
#  '45/47-1': 'Qin Zhang 0001',
#  '181/2689-1': 'Qing Li 0001',
#  '66/3005': 'Qingkai Zeng',
#  '169/1808': 'Qingyao Ai',
#  'l/QiongLuo': 'Qiong Luo 0001',
#  '50/4597': 'Quanquan Gu',
#  '11/1466': 'R. Uday Kiran',
#  '68/1297': 'Rachel Pottinger',
#  '01/3589': 'Rada Chirkova',
#  '205/9137': 'Rajmohan C',
#  '68/1677': 'Raju Balakrishnan',
#  '48/10806': 'Rakesh Malladi',
#  's/RalfSchenkel': 'Ralf Schenkel',
#  '91/275': 'Raluca A. Popa',
#  '56/3378': 'Ramasuri Narayanam',
#  '245/6042': 'Ran Le',
#  '241/7225': 'Raoni Lourenço',
#  '131/4202': 'Raul Castro Fernandez',
#  '62/150': 'Ravi Kiran Sarvadevabhatla',
#  '02/4973': 'Ravishankar Ramamurthy',
#  'w/RaymondChiWingWong': 'Raymond Chi-Wing Wong',
#  '13/7406': 'Razieh Rahimi',
#  '147/1198': 'Rebecca Taft',
#  '185/9964': 'Yisu Remy Wang',
#  '36/10568': 'Renata Borovica',
#  'm/ReneMuller': 'René Müller 0001',
#  'm/RJMiller': 'Renée J. Miller',
#  '137/9588': 'Renfen Hu',
#  '204/0158': 'Renqin Cai',
#  's/RenukaSindhgatta': 'Renuka Sindhgatta',
#  '89/2619': 'Reynold Cheng',
#  '25/3618': 'Reza Akbarinia',
#  '169/8184': 'Riccardo Tommasini 0001',
#  't/RiccardoTorlone': 'Riccardo Torlone',
#  '75/3512': 'Richa Singh 0001',
#  '29/7184': 'Richard McCreadie',
#  '121/4289': 'Rishabh Mehrotra',
#  '129/1674': 'Rishi Ranjan Singh',
#  '96/7128': 'Rishiraj Saha Roy',
#  '127/3163': 'Ritwik Sinha',
#  '79/1490': 'Roger Zimmermann',
#  '228/2573': 'Roman Vainshtein',
#  '37/548': 'Ronghua Li',
#  '23/1886': 'Ruggero G. Pensa',
#  '218/9188': 'Ruhi Sharma Mittal',
#  '51/5793': 'Rui Mao 0001',
#  '19/2405-1': 'Rui Yan 0001',
#  '03/505': 'Rui Zhang 0003',
#  '178/8590': 'Ruobing Xie',
#  '72/4662': 'Ruoming Jin',
#  '203/8270': 'Ruqing Zhang',
#  '98/3414-1': 'Ryan Johnson 0001',
#  '175/1473': 'Ryan Marcus',
#  '137/8445': 'Ryan Rogers 0002',
#  '17/5085': 'Ryan A. Rossi',
#  's/SSudarshan1': 'S. Sudarshan 0001',
#  '74/9877': 'Sabine Storandt',
#  '96/2418': 'Sachindra Joshi',
#  '26/101': 'Saeed Salem',
#  '90/2736': 'Sahely Bhadra',
#  '213/4131': 'Sahil Chelaramani',
#  '30/1186': 'Sai Wu',
#  '136/7969': 'Sainyam Galhotra',
#  '168/0294': 'Sajjadur Rahman',
#  '55/1967': 'Saket Sathe 0001',
#  '22/835-1': 'Salil Joshi 0001',
#  '98/7258': 'Sam Idicula',
#  '71/1647': 'Sambuddha Roy',
#  'm/SamuelMadden': 'Samuel Madden',
#  '11/7555': 'Sandeep Hans',
#  '20/1055': 'Sandeep Tata',
#  '139/2312': 'Sandipan Sikdar',
#  'l/SangWonLee': 'Sang-Won Lee 0001',
#  '147/1189': 'Sanjay Krishnan',
#  '50/7626': 'Sanjay Purushotham',
#  '92/6085': 'Sanjib Das',
#  '06/900-1': 'Saptarshi Ghosh 0001',
#  'c/SaraCohen': 'Sara Cohen',
#  '57/10514': 'Saravanan Thirumuruganathan',
#  '41/5564': 'Sathya Peri',
#  '38/768': 'Sayan Ranu',
#  'w/XiaoyangSeanWang': 'Xiaoyang Sean Wang',
#  'g/SergioGreco': 'Sergio Greco',
#  '82/4089': 'Shady Elbassuoni',
#  'g/SGhandeharizadeh': 'Shahram Ghandeharizadeh',
#  '143/6186': 'Amir Shaikhha',
#  '94/2844': 'Shan-Hung Wu',
#  '70/4688': 'Shanmuganathan Raman',
#  '149/1281': 'Shanshan Feng',
#  '38/3523': 'Shantanu Godbole',
#  '83/2389-1': 'Shantanu Sharma 0001',
#  '20/3883': 'Shaoxu Song',
#  'm/SharadMehrotra': 'Sharad Mehrotra',
#  's/ShashiShekhar': 'Shashi Shekhar',
#  '98/2324': 'Shel Finkelstein',
#  '85/7967': 'Shen Gao',
#  '85/1868-11': 'Sheng Wang 0011',
#  '85/1868': 'Sheng Wang',
#  '85/1868-7': 'Sheng Wang 0007',
#  '217/7022': 'Shengchao Liu',
#  'c/ShiminChen': 'Shimin Chen',
#  '35/3834': 'Shirish Tatikonda',
#  '43/5188': 'Shivali Agarwal',
#  '131/9481': 'Shixuan Sun',
#  '94/10440': 'Shoaib Jameel',
#  '21/5967': 'Lidan Shou',
#  '168/9023': 'Shoumik Palkar',
#  '96/3834': 'Shourya Roy',
#  '143/7236': 'Shrainik Jain',
#  '124/7268': 'Shrutendra Harsola',
#  '35/6569': 'Shuai Ma 0001',
#  'c/ShuChingChen': 'Shu-Ching Chen',
#  'b/SSBhowmick': 'Sourav S. Bhowmick',
#  '127/0212': 'Sowmya Vajjala',
#  '01/5237': 'Spiros Skiadopoulos',
#  '65/5338': 'Spyros Blanas',
#  '119/1402': 'Sreenivasa Kumar Puligundla',
#  '76/1783': 'Sridhar Chimalakonda',
#  '131/9628': 'Srijan Kumar',
#  'b/SrikantaJBedathur': 'Srikanta J. Bedathur',
#  '05/5881': 'Stelios Paparizos',
#  'b/SBressan': 'Stéphane Bressan',
#  'w/StevenEuijongWhang': 'Steven Euijong Whang',
#  '28/3797': 'Stijn Vansummeren',
#  'i/StratosIdreos': 'Stratos Idreos',
#  '139/7927': 'Subarna Chatterjee',
#  '190/1709': 'Subba Reddy Oota',
#  '158/4862': 'Subhadeep Sarkar',
#  '77/4620': 'Sudeepa Roy',
#  '61/3197': 'Sudeshna Sarkar',
#  '21/5625': 'Sudhanshu Singh',
#  '44/4775-2': 'Sudip Roy 0002',
#  '71/5974': 'Sudipto Das',
#  '03/6702': 'Sujatha Das Gollapalli',
#  '46/1330': 'Sumio Fujita',
#  '61/1573': 'Sungchul Kim',
#  '93/5196': 'Sungpack Hong',
#  '251/9524': 'Sunil Kumar Maurya',
#  '204/3779': 'Suppanut Pothirattanachaikul',
#  '26/11046': 'Supratim Ghosh',
#  '19/5099': 'Suprio Ray',
#  '182/0250': 'Supun Nakandala',
#  'c/SurajitChaudhuri': 'Surajit Chaudhuri',
#  'h/SvenHartmann': 'Sven Hartmann',
#  'h/SvenHelmer': 'Sven Helmer',
#  '40/2808': 'Takahiro Hara',
#  '38/4395': 'Takehiro Yamamoto',
#  '99/5856': 'Tamer Elsayed',
#  'o/MTamerOzsu': 'M. Tamer Özsu',
#  '11/7631': 'Tanmay Basu',
#  'm/TanuMalik': 'Tanu Malik',
#  '31/11538': 'Tanuja Ganu',
#  '179/2728': 'Tarique Siddiqui',
#  '10/760': 'Tilmann Rabl',
#  '26/6037': 'Tim Kraska',
#  '73/2015': 'Tim Weninger',
#  's/TimosKSellis': 'Timos K. Sellis',
#  '19/2205': 'Ting Deng',
#  '12/2633-6': 'Ting Wang 0006',
#  'y/TingYu': 'Ting Yu',
#  '25/2228': 'Tingjian Ge',
#  '56/7911': 'Tingwen Liu',
#  '72/36': 'Tirthankar Dasgupta',
#  '183/0983': 'Tobias Grubenmann',
#  '69/159': 'Tony Tan',
#  'c/ToonCalders': 'Toon Calders',
#  'p/TorbenBachPedersen': 'Torben Bach Pedersen',
#  'g/TorstenGrust': 'Torsten Grust',
#  'a/TAmagasa': 'Toshiyuki Amagasa',
#  'm/TovaMilo': 'Tova Milo',
#  '05/1478': 'Tristan Allard',
#  '77/1703': 'Tsuyoshi Murata',
#  '166/7652': 'Tsz Nam Chan',
#  '25/9994': 'Tuan-Anh Hoang',
#  '07/1751': 'Udo Kruschwitz',
#  '199/6350': 'Ugo Comignani',
#  'c/UgurCetintemel': 'Ugur Çetintemel',
#  'l/UlfLeser': 'Ulf Leser',
#  '99/6349': 'Umar Farooq Minhas',
#  'r/UweRohm': 'Uwe Röhm',
#  '68/3004': 'V. Susheela Devi',
#  '67/6469': 'V. G. Vinod Vydiswaran',
#  '42/5855': 'Vagelis Hristidis',
#  't/ValTannen': 'Val Tannen',
#  'k/VanaKalogeraki': 'Vana Kalogeraki',
#  '84/2055': 'Vanessa Braganholo',
#  '51/10288': 'Varish Mulwad',
#  '132/6943': 'Vasiliki Kalavri',
#  '87/11444': 'Vasilis Efthymiou',
#  'v/VVassalos': 'Vasilis Vassalos',
#  '94/1028': 'Vassilios S. Verykios',
#  'c/VassilisChristophides': 'Vassilis Christophides',
#  '03/4045': 'Vasudeva Varma',
#  'c/VTChakaravarthy': 'Venkatesan T. Chakaravarthy',
#  '156/1280': 'Venkatesh Vinayakarao',
#  'k/VerenaKantere': 'Verena Kantere',
#  '199/6298': 'Victor Junqiu Wei',
#  '151/5215': 'Victor Zakhary',
#  '77/1485': 'Vijay Arya',
#  '06/8397': 'Vijay Gabale',
#  'r/VijayshankarRaman': 'Vijayshankar Raman',
#  '23/816': 'Vikas C. Raykar',
#  '70/6404': 'Vikram Goyal',
#  '80/594': 'Vikram Pudi',
#  '10/11150': 'Viktor Leis',
#  '02/7933': 'Vincent Leroy 0001',
#  'o/VincentOria': 'Vincent Oria',
#  't/VincentSMTseng': 'Vincent S. Tseng',
#  '88/995': 'Vineet Chaoji',
#  '162/6966': 'Vinu E. Venugopal',
#  '56/4585': 'Vishwa Vinay',
#  '83/7998': 'Viswanath Gunturi',
#  'n/VivekRNarasayya': 'Vivek R. Narasayya',
#  'o/VivianeMoreiraOrengo': 'Viviane Pereira Moreira',
#  'm/VMarkl': 'Volker Markl',
#  '174/9539': 'Vraj Shah',
#  'm/WagnerMeiraJr': 'Wagner Meira Jr.',
#  '48/1707': 'Wai Lam',
#  'a/WGAref': 'Walid G. Aref',
#  '90/7457': 'Walter Cai',
#  '172/0874': 'Wang-Cheng Kang',
#  '14/716': 'Wang-Chien Lee',
#  't/WangChiewTan': 'Wang Chiew Tan',
#  '149/9304': 'Abdul Wasay',
#  'c/WeiChen1': 'Wei Chen 0001',
#  '89/2506-2': 'Wei Cheng 0002',
#  '98/6613-15': 'Wei Lu 0015',
#  '35/7092-59': 'Wei Wang 0059',
#  'w/WeiWang9': 'Wei Wang 0009',
#  '35/7092-30': 'Wei Wang 0030',
#  'w/WeiWang11': 'Wei Wang 0011',
#  'w/WeiWang': 'Wei Wang 0010',
#  '28/10261-3': 'Weinan Zhang 0003',
#  '55/3364': 'Weining Qian',
#  '45/8097': 'Weiren Yu',
#  '21/1694': 'Wei-Shinn Ku',
#  '30/841': 'Weiwei Gong',
#  '49/8024': 'Weize Kong',
#  '169/1390': 'Weizhi Ma',
#  '68/11145': 'Wen Hua',
#  'l/WLehner': 'Wolfgang Lehner',
#  '146/6282': 'Wolfram Wingerath',
#  '62/2450': 'Wook-Shin Han',
#  'h/WynneHsu': 'Wynne Hsu',
#  '28/949-1': 'Xi He 0001',
#  '40/1491-33': 'Xiang Li 0033',
#  'l/XianLian': 'Xiang Lian',
#  '07/668-2': 'Xiang Zhao 0002',
#  '06/8315': 'Xiangnan Kong',
#  '126/6015': 'Xiangyao Yu',
#  'z/XiaofangZhou': 'Xiaofang Zhou 0001',
#  '83/4809-2': 'Xiaofei Zhang 0002',
#  '33/1903': 'Xiaokui Xiao',
#  '117/4879-1': 'Xiaolan Wang 0001',
#  '81/1832-2': 'Xiaoyang Wang 0002',
#  '47/3542-1': 'Xiaoyong Du 0001',
#  '126/2338-1': 'Xiaxia Wang 0001',
#  'y/XifengYan': 'Xifeng Yan',
#  '130/1013': 'Ximing Li',
#  '77/2970-1': 'Xin Cao 0001',
#  '98/5766-1': 'Xin Huang 0001',
#  '76/1820-20': 'Xin Liu 0020',
#  '10/5630-1': 'Xin Wang 0001',
#  '35/1895-1': 'Xin Xin 0001',
#  '52/8700': 'Wayne Xin Zhao',
#  '08/6809-1': 'Xing Xie 0001',
#  '19/189': 'Xiubo Geng',
#  '152/8201': 'Xiucheng Li',
#  '131/4767': 'Xu Chu',
#  '19/3011': 'Xu Han',
#  '13/5407-5': 'Xuan Liu 0005',
#  'l/LinXuemin': 'Xuemin Lin 0001',
#  '23/2460': 'Xueyan Tang',
#  '127/0138': 'Yadollah Yaghoobzadeh',
#  '88/9060': 'Yael Amsterdamer',
#  '25/7045-11': 'Yang Cao 0011',
#  '25/7045-12': 'Yang Cao 0012',
#  ...}

# %%
# Remove individuals not in the network
network_df = network_df[network_df['author_pid'].isin(pid_list)]
network_df = network_df[network_df['coauthor_pid'].isin(pid_list)]
network_df
# Out:
#        author_pid  coauthor_pid  year  \
# 2         75/9436      163/0545  2021
# 5         75/9436      163/0545  2021
# 10        75/9436  f/MJFranklin  2021
# 11        75/9436      147/1189  2021
# 13        75/9436      117/3757  2021
# ...           ...           ...   ...
# 362916   146/6971  w/YangWang15  2019
# 362920   146/6971       86/1747  2019
# 362926   146/6971       86/1747  2019
# 362935   146/6971       86/1747  2019
# 362939   146/6971       86/1747  2019
#
#                                                     title
# 2       Decomposed Bounded Floats for Fast Compression...
# 5       VergeDB: A Database for IoT Analytics on Edge ...
# 10      VergeDB: A Database for IoT Analytics on Edge ...
# 11      VergeDB: A Database for IoT Analytics on Edge ...
# 13      Version Reconciliation for Collaborative Datab...
# ...                                                   ...
# 362916  sharedCharging: Data-Driven Shared Charging fo...
# 362920  Rhetorically Controlled Encoder-Decoder for Mo...
# 362926  Reinforcement Knowledge Graph Reasoning for Ex...
# 362935  OOGAN: Disentangling GAN with One-Hot Sampling...
# 362939  Reinforcement Knowledge Graph Reasoning for Ex...
#
# [64474 rows x 4 columns]

# %%
network_df['author_name'] = network_df.apply(lambda d: pid_name_mapping[d['author_pid']], axis=1)
network_df['coauthor_name'] = network_df.apply(lambda d: pid_name_mapping[d['coauthor_pid']], axis=1)

# %%
network_df['check_duplicates'] = network_df.apply(lambda d: ''.join(sorted([str(d['author_pid']),
                                                                            str(d['coauthor_pid']),
                                                                            str(d['title']),
                                                                            str(d['year'])
                                                                           ])), axis=1)
network_df
# Out:
#        author_pid  coauthor_pid  year  \
# 2         75/9436      163/0545  2021
# 5         75/9436      163/0545  2021
# 10        75/9436  f/MJFranklin  2021
# 11        75/9436      147/1189  2021
# 13        75/9436      117/3757  2021
# ...           ...           ...   ...
# 362916   146/6971  w/YangWang15  2019
# 362920   146/6971       86/1747  2019
# 362926   146/6971       86/1747  2019
# 362935   146/6971       86/1747  2019
# 362939   146/6971       86/1747  2019
#
#                                                     title      author_name  \
# 2       Decomposed Bounded Floats for Fast Compression...  Aaron J. Elmore
# 5       VergeDB: A Database for IoT Analytics on Edge ...  Aaron J. Elmore
# 10      VergeDB: A Database for IoT Analytics on Edge ...  Aaron J. Elmore
# 11      VergeDB: A Database for IoT Analytics on Edge ...  Aaron J. Elmore
# 13      Version Reconciliation for Collaborative Datab...  Aaron J. Elmore
# ...                                                   ...              ...
# 362916  sharedCharging: Data-Driven Shared Charging fo...        Zuohui Fu
# 362920  Rhetorically Controlled Encoder-Decoder for Mo...        Zuohui Fu
# 362926  Reinforcement Knowledge Graph Reasoning for Ex...        Zuohui Fu
# 362935  OOGAN: Disentangling GAN with One-Hot Sampling...        Zuohui Fu
# 362939  Reinforcement Knowledge Graph Reasoning for Ex...        Zuohui Fu
#
#               coauthor_name                                   check_duplicates
# 2           John Paparrizos  163/0545202175/9436Decomposed Bounded Floats f...
# 5           John Paparrizos  163/0545202175/9436VergeDB: A Database for IoT...
# 10      Michael J. Franklin  202175/9436VergeDB: A Database for IoT Analyti...
# 11          Sanjay Krishnan  147/1189202175/9436VergeDB: A Database for IoT...
# 13             Zechao Shang  117/3757202175/9436Version Reconciliation for ...
# ...                     ...                                                ...
# 362916       Yang Wang 0015  146/69712019sharedCharging: Data-Driven Shared...
# 362920       Gerard de Melo  146/6971201986/1747Rhetorically Controlled Enc...
# 362926       Gerard de Melo  146/6971201986/1747Reinforcement Knowledge Gra...
# 362935       Gerard de Melo  146/6971201986/1747OOGAN: Disentangling GAN wi...
# 362939       Gerard de Melo  146/6971201986/1747Reinforcement Knowledge Gra...
#
# [64474 rows x 7 columns]

# %%
network_df.drop_duplicates('check_duplicates', inplace=True)
network_df = network_df.drop('check_duplicates', 1)
network_df
# Out:
#        author_pid  coauthor_pid  year  \
# 2         75/9436      163/0545  2021
# 5         75/9436      163/0545  2021
# 10        75/9436  f/MJFranklin  2021
# 11        75/9436      147/1189  2021
# 13        75/9436      117/3757  2021
# ...           ...           ...   ...
# 358563   189/2405       20/3716  2019
# 358588   189/2405       20/3716  2018
# 358590   189/2405       20/3716  2018
# 358594   189/2405       20/3716  2017
# 358797   169/3426      169/3419  2015
#
#                                                     title      author_name  \
# 2       Decomposed Bounded Floats for Fast Compression...  Aaron J. Elmore
# 5       VergeDB: A Database for IoT Analytics on Edge ...  Aaron J. Elmore
# 10      VergeDB: A Database for IoT Analytics on Edge ...  Aaron J. Elmore
# 11      VergeDB: A Database for IoT Analytics on Edge ...  Aaron J. Elmore
# 13      Version Reconciliation for Collaborative Datab...  Aaron J. Elmore
# ...                                                   ...              ...
# 358563  Balance-Aware Distributed String Similarity-Ba...     Zeyuan Shang
# 358588  DITA: Distributed In-Memory Trajectory Analytics.     Zeyuan Shang
# 358590  DITA: A Distributed In-Memory Trajectory Analy...     Zeyuan Shang
# 358594  Dima: A Distributed In-Memory Similarity-Based...     Zeyuan Shang
# 358797       SINGA: A Distributed Deep Learning Platform.     Zhaojing Luo
#
#               coauthor_name
# 2           John Paparrizos
# 5           John Paparrizos
# 10      Michael J. Franklin
# 11          Sanjay Krishnan
# 13             Zechao Shang
# ...                     ...
# 358563          Zhifeng Bao
# 358588          Zhifeng Bao
# 358590          Zhifeng Bao
# 358594          Zhifeng Bao
# 358797          Zhongle Xie
#
# [31030 rows x 6 columns]

# %% [markdown]
# ### 5. Save processed data

# %%
# Save processed
network_df.to_csv(processed_output_filepath, index=False)
